# %% [markdown]
# #### This is the code for named entity recognition. The final model chosen for the thesis

# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls /content/drive/
# Out:
# Mounted at /content/drive
# MyDrive

# %% [markdown]
# # Ner bert

# %%
# !pip install pandas
# !pip install nltk
# !pip install transformers
# !pip install tqdm
# !pip install spacy
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import pandas as pd
import nltk
from tqdm import tqdm
from transformers import BertTokenizer, BertForTokenClassification, BertConfig
from transformers import pipeline
import ast
import spacy
from collections import Counter

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import pandas as pd
import nltk
from tqdm import tqdm
from transformers import BertTokenizer, BertForTokenClassification, BertConfig
from transformers import pipeline
from colletions import Counter
nltk.download('punkt')

# Read the CSV file
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/coal_data_filtered_nodup_cleaned3.csv'
df = pd.read_csv(path_to_csv)

# Load the file with the info on top topic per document
path_to_df_top = '/content/drive/MyDrive/Colab Notebooks/topic_model_3_k20_srl.csv'
df_top = pd.read_csv(path_to_df_top)

# Merge the datasets based on id column
df = df.merge(df_top, left_on='Unnamed: 0.1', right_on='Unnamed: 0.1', how='left')

print("Merged DataFrame:")
print(df.head())

# Filter out the topics of interest
#topics_of_interest = ["Climate change & climate finance", "Renewable energy projects", "Labour unions & strikes", "Climate change damages"]
#df = df[df['Dominant Topic'].isin(topics_of_interest)]

df_subset = df['Article_Text'].head(200)

# Initialize an empty list to store sentences
sentences = []

# Tokenizer for checking sentence length
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

# Function to truncate sentences
def truncate_sentence(sentence, max_length=50):
    words = sentence.split()
    if len(words) > max_length:
        sentence = ' '.join(words[:max_length])
    return sentence

# Iterate over the text of the articles
for text in df_subset:
    # Split the text into sentences using NLTK's sent_tokenize function
    text_sentences = nltk.sent_tokenize(text)
    # Check each sentence for the presence of the word "coal"
    for sentence in text_sentences:
        # Convert the sentence to lowercase for case-insensitive matching
        sentence_lower = sentence.lower()
        # Check if the sentence contains the word "coal"
        if "coal" in sentence_lower:
            truncated_sentence = truncate_sentence(sentence)
            sentences.append(truncated_sentence)

# Load the pre-trained NER model and tokenizer
ner_model = pipeline("ner", model='dslim/bert-base-NER', tokenizer='dslim/bert-base-NER')

# Function to predict entities
def predict_ner(sentences):
    predictions = []
    for sentence in tqdm(sentences, desc="Predicting NER"):
        pred = ner_model(sentence)
        predictions.append(pred)
    return predictions

# Run prediction
predictions = predict_ner(sentences)

# Create an empty list to store the data
data = []

for sentence, prediction in zip(sentences, predictions):
    sentence_text = sentence
    entities = {ent['entity']: ent['word'] for ent in prediction}
    data.append([sentence_text, entities])

# Create a DataFrame from the data list
df_ner = pd.DataFrame(data, columns=['Sentence', 'Entities'])

# Export the DataFrame as a CSV file
#df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_top_topic.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Merged DataFrame:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2         168
# 1             3         261
# 2             4         263
# 3             5         360
# 4             6         361
#
#                                         Jurisdiction  Location ContentType  \
# 0                                      International       NaN        News
# 1                                      International       NaN        News
# 2  U.S. Federal; International; Massachusetts; Wa...       NaN        News
# 3                                      International       NaN        News
# 4                                      International       NaN        News
#
#             Byline  WordLength  WebNewsUrl  Geography  NegativeNews  ...  \
# 0              NaN        1860         NaN        NaN           NaN  ...
# 1     Ingi Salgado         700         NaN        NaN           NaN  ...
# 2     Patrick Bond        1768         NaN        NaN           NaN  ...
# 3  Eleanor Momberg         867         NaN        NaN           NaN  ...
# 4  Donwald Pressly         440         NaN        NaN           NaN  ...
#
#                                         Article_Text  \
# 0  AS WITH many a passion, one\'s earliest beginn...
# 1  Instead, business organisations, municipalitie...
# 2  Today\'s meeting of the Brazil, South Africa, ...
# 3  RECYCLED effluent from Gauteng will be used to...
# 4  Public enterprises committee members were this...
#
#                                     City  State  \
# 0                CAPE TOWN, SOUTH AFRICA    NaN
# 1                                    NaN    NaN
# 2  COPENHAGEN, DENMARK; NEW DELHI, INDIA  EARTH
# 3                                    NaN    NaN
# 4                                    NaN    NaN
#
#                                              Country  \
# 0                                       SOUTH AFRICA
# 1                      SOUTH AFRICA; SOUTHERN AFRICA
# 2  SOUTH AFRICA; INDIA; AFRICA; BRAZIL; CHINA; UN...
# 3                                       SOUTH AFRICA
# 4                                       SOUTH AFRICA
#
#                              News Outlet  \
# 0  The Sunday Independent (South Africa)
# 1  The Sunday Independent (South Africa)
# 2  The Sunday Independent (South Africa)
# 3  The Sunday Independent (South Africa)
# 4  The Sunday Independent (South Africa)
#
#                                  Word Count  ArticleCount  frequency version  \
# 0                   LIFE; Pg. 30, 1860words           368     weekly   print
# 1  BUSINESS REPORT WEEKEND; Pg. 1, 700words           368     weekly   print
# 2                           NEWS, 1768words           368     weekly   print
# 3                    NEWS; Pg. 10, 867words           368     weekly   print
# 4  BUSINESS REPORT WEEKEND; Pg. 1, 440words           368     weekly   print
#
#                      Dominant Topic
# 0                    Arts & culture
# 1                   Eskom financing
# 2  Climate change & climate finance
# 3   Environmental impacts of mining
# 4               Power supply issues
#
# [5 rows x 52 columns]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/829 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/59.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Predicting NER: 100%|██████████| 453/453 [01:25<00:00,  5.31it/s]
#                                              Sentence  \
# 0   Then to swim out beyond the breakers, the sea ...
# 1   Environmental groups rejected the dominance of...
# 2   "We\'re confident this will prove more cost-ef...
# 3   They contrast the ineffectual "pork-laden" leg...
# 4   The major bills are now being pushed by John K...
# 5   The boiler deals give the ruling party a multi...
# 6   In reality, cuts promised in the Long-Term Mit...
# 7   As the Eskom tariff hearings organised by the ...
# 8   RECYCLED effluent from Gauteng will be used to...
# 9   The department called this month for public co...
# 10  The conservation-rich Waterberg was estimated ...
# 11  Several mines are expected to be developed in ...
# 12  The department said this week that because sub...
# 13  Public enterprises committee members were this...
# 14  Committee chairperson Vytjie Mentor, an ANC MP...
# 15  His comments came after Eskom\'s generation he...
# 16  Mentor, whose committee called Eskom and the c...
# 17  It emerged that three major coal suppliers - A...
# 18  They all run so-called tied mines where Eskom ...
# 19  Xstrata, which also addressed the committee, s...
#
#                                              Entities
# 0               {'B-PER': '##tte', 'I-PER': '##isse'}
# 1                      {'B-ORG': 'E', 'I-ORG': '##m'}
# 2   {'B-ORG': 'E', 'I-ORG': '##m', 'B-PER': 'Sue',...
# 3   {'B-ORG': 'Ch', 'I-ORG': 'San', 'B-LOC': 'West...
# 4             {'B-PER': 'Lindsay', 'I-PER': 'Graham'}
# 5                                                  {}
# 6   {'B-MISC': 'Long', 'I-MISC': '##rio', 'B-ORG':...
# 7                      {'B-ORG': 'E', 'I-ORG': '##m'}
# 8   {'B-LOC': 'Lim', 'I-LOC': '##o', 'B-ORG': 'Wat...
# 9   {'B-ORG': 'MC', 'I-ORG': '##P', 'I-LOC': '##m'...
# 10              {'B-LOC': 'South', 'I-LOC': 'Africa'}
# 11  {'B-ORG': 'E', 'I-ORG': '##m', 'B-LOC': '##it'...
# 12                 {'B-LOC': 'Lim', 'I-LOC': 'River'}
# 13                     {'B-ORG': 'E', 'I-ORG': '##m'}
# 14  {'B-PER': 'Jacob', 'I-PER': '##oga', 'B-ORG': ...
# 15  {'B-ORG': 'E', 'I-ORG': '##m', 'B-PER': 'Brian...
# 16  {'B-PER': 'Mar', 'B-ORG': 'E', 'I-ORG': '##m',...
# 17                     {'B-ORG': 'E', 'I-ORG': '##m'}
# 18                     {'B-ORG': 'E', 'I-ORG': '##m'}
# 19                     {'B-ORG': 'E', 'I-ORG': '##m'}

# %%
df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_top_topic.csv', index=False)

# %% [markdown]
# # Ner spacy

# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.7.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.25.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.6.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.16.1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.14.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import pandas as pd
import nltk
from tqdm import tqdm
import spacy
nltk.download('punkt')

# Read the CSV file
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/coal_data_filtered_nodup_cleaned3.csv'
df = pd.read_csv(path_to_csv)

# Load the file with the info on top topic per document
path_to_df_top = '/content/drive/MyDrive/Colab Notebooks/topic_model_3_k20_srl.csv'
df_top = pd.read_csv(path_to_df_top)

# Merge the datasets based on id column
df = df.merge(df_top, left_on='Unnamed: 0.1', right_on='Unnamed: 0.1', how='left')

print("Merged DataFrame:")
print(df.head())

# Filter out the topics of interest
topics_of_interest = ["Transition politics & climate finance", "Energy policies & renewables", "Oil & gas alternatives", "Climate change impact", "Coal labor issues"]
df = df[df['Dominant Topic'].isin(topics_of_interest)]

df_subset = df['Article_Text'].head(200)

# Initialize an empty list to store sentences
sentences = []

# Function to truncate sentences
def truncate_sentence(sentence, max_length=50):
    words = sentence.split()
    if len(words) > max_length:
        sentence = ' '.join(words[:max_length])
    return sentence

# Iterate over the text of the articles
for text in df_subset:
    # Split the text into sentences using NLTK's sent_tokenize function
    text_sentences = nltk.sent_tokenize(text)
    # Check each sentence for the presence of the word "coal"
    for sentence in text_sentences:
        # Convert the sentence to lowercase for case-insensitive matching
        sentence_lower = sentence.lower()
        # Check if the sentence contains the word "coal"
        if "coal" in sentence_lower:
            truncated_sentence = truncate_sentence(sentence)
            sentences.append(truncated_sentence)

# Load the pre-trained spaCy model for NER
nlp = spacy.load('en_core_web_sm')

# Function to predict entities using spaCy
def predict_ner_spacy(sentences):
    predictions = []
    for sentence in tqdm(sentences, desc="Predicting NER with spaCy"):
        doc = nlp(sentence)
        entities = {ent.text: ent.label_ for ent in doc.ents}
        predictions.append(entities)
    return predictions

# Run prediction
predictions = predict_ner_spacy(sentences)

# Create an empty list to store the data
data = []

for sentence, entities in zip(sentences, predictions):
    data.append([sentence, entities])

# Create a DataFrame from the data list
df_ner = pd.DataFrame(data, columns=['Sentence', 'Entities'])

# Export the DataFrame as a CSV file
df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_spacy_dtm_top_topic.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Merged DataFrame:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2         168
# 1             3         261
# 2             4         263
# 3             5         360
# 4             6         361
#
#                                         Jurisdiction  Location ContentType  \
# 0                                      International       NaN        News
# 1                                      International       NaN        News
# 2  U.S. Federal; International; Massachusetts; Wa...       NaN        News
# 3                                      International       NaN        News
# 4                                      International       NaN        News
#
#             Byline  WordLength  WebNewsUrl  Geography  NegativeNews  ...  \
# 0              NaN        1860         NaN        NaN           NaN  ...
# 1     Ingi Salgado         700         NaN        NaN           NaN  ...
# 2     Patrick Bond        1768         NaN        NaN           NaN  ...
# 3  Eleanor Momberg         867         NaN        NaN           NaN  ...
# 4  Donwald Pressly         440         NaN        NaN           NaN  ...
#
#                                         Article_Text  \
# 0  AS WITH many a passion, one\'s earliest beginn...
# 1  Instead, business organisations, municipalitie...
# 2  Today\'s meeting of the Brazil, South Africa, ...
# 3  RECYCLED effluent from Gauteng will be used to...
# 4  Public enterprises committee members were this...
#
#                                     City  State  \
# 0                CAPE TOWN, SOUTH AFRICA    NaN
# 1                                    NaN    NaN
# 2  COPENHAGEN, DENMARK; NEW DELHI, INDIA  EARTH
# 3                                    NaN    NaN
# 4                                    NaN    NaN
#
#                                              Country  \
# 0                                       SOUTH AFRICA
# 1                      SOUTH AFRICA; SOUTHERN AFRICA
# 2  SOUTH AFRICA; INDIA; AFRICA; BRAZIL; CHINA; UN...
# 3                                       SOUTH AFRICA
# 4                                       SOUTH AFRICA
#
#                              News Outlet  \
# 0  The Sunday Independent (South Africa)
# 1  The Sunday Independent (South Africa)
# 2  The Sunday Independent (South Africa)
# 3  The Sunday Independent (South Africa)
# 4  The Sunday Independent (South Africa)
#
#                                  Word Count  ArticleCount  frequency version  \
# 0                   LIFE; Pg. 30, 1860words           368     weekly   print
# 1  BUSINESS REPORT WEEKEND; Pg. 1, 700words           368     weekly   print
# 2                           NEWS, 1768words           368     weekly   print
# 3                    NEWS; Pg. 10, 867words           368     weekly   print
# 4  BUSINESS REPORT WEEKEND; Pg. 1, 440words           368     weekly   print
#
#                      Dominant Topic
# 0                    Arts & culture
# 1                   Eskom financing
# 2  Climate change & climate finance
# 3   Environmental impacts of mining
# 4               Power supply issues
#
# [5 rows x 52 columns]
# Predicting NER with spaCy: 0it [00:00, ?it/s]
# Empty DataFrame
# Columns: [Sentence, Entities]
# Index: []

# %%
# Read the CSV file
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/coal_data_filtered_nodup_cleaned3.csv'
df = pd.read_csv(path_to_csv)

# Load the file with the info on top topic per document
path_to_df_top = '/content/drive/MyDrive/Colab Notebooks/topic_model_3_k20_srl_2.csv'
df_top = pd.read_csv(path_to_df_top)


# Merge the datasets based on id column
df = df.merge(df_top, left_on='Unnamed: 0.1', right_on='Unnamed: 0.1', how='left')

print("Merged DataFrame:")
print(df.head())

# List unique topics in the DataFrame
unique_topics = df['Dominant Topic'].unique()
print("Unique topics in the DataFrame:", unique_topics)

# Filter out the topics of interest
topics_of_interest = ["Transition politics & climate finance", "Energy policies & renewables", "Oil & gas alternatives", "Climate change impact", "Coal labor issues"]
df = df[df['Dominant Topic'].isin(topics_of_interest)]

print(f"Filtered DataFrame has {len(df)} rows after filtering by topics.")

# Extract necessary columns
df_subset = df[['Article_Text', 'Dominant Topic']]

print(f"Subset DataFrame has {len(df_subset)} rows.")

# Initialize an empty list to store sentences and topics
data = []

# Function to truncate sentences
def truncate_sentence(sentence, max_length=50):
    words = sentence.split()
    if len(words) > max_length:
        sentence = ' '.join(words[:max_length])
    return sentence

# Iterate over the text of the articles
for index, row in df_subset.iterrows():
    text = row['Article_Text']
    topic = row['Dominant Topic']
    # Split the text into sentences using NLTK's sent_tokenize function
    text_sentences = nltk.sent_tokenize(text)
    # Check each sentence for the presence of the word "coal"
    for sentence in text_sentences:
        # Convert the sentence to lowercase for case-insensitive matching
        sentence_lower = sentence.lower()
        # Check if the sentence contains the word "coal"
        if "coal" in sentence_lower:
            truncated_sentence = truncate_sentence(sentence)
            data.append((truncated_sentence, topic))

print(f"Collected {len(data)} sentences containing the word 'coal'.")

# Load the pre-trained spaCy model for NER
nlp = spacy.load('en_core_web_sm')

# Function to predict entities using spaCy
def predict_ner_spacy(data):
    predictions = []
    for sentence, topic in tqdm(data, desc="Predicting NER with spaCy"):
        doc = nlp(sentence)
        entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['PERSON', 'ORG']]
        predictions.append((sentence, topic, entities))
    return predictions

# Run prediction
predictions = predict_ner_spacy(data)

# Create an empty list to store the data for the DataFrame
df_data = []

for sentence, topic, entities in predictions:
    df_data.append([sentence, topic, entities])

# Create a DataFrame from the data list
df_ner = pd.DataFrame(df_data, columns=['Sentence', 'Dominant Topic', 'Entities'])

# Export the DataFrame as a CSV file
df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy_top_topic.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))
# Out:
# Merged DataFrame:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2         168
# 1             3         261
# 2             4         263
# 3             5         360
# 4             6         361
#
#                                         Jurisdiction  Location ContentType  \
# 0                                      International       NaN        News
# 1                                      International       NaN        News
# 2  U.S. Federal; International; Massachusetts; Wa...       NaN        News
# 3                                      International       NaN        News
# 4                                      International       NaN        News
#
#             Byline  WordLength  WebNewsUrl  Geography  NegativeNews  ...  \
# 0              NaN        1860         NaN        NaN           NaN  ...
# 1     Ingi Salgado         700         NaN        NaN           NaN  ...
# 2     Patrick Bond        1768         NaN        NaN           NaN  ...
# 3  Eleanor Momberg         867         NaN        NaN           NaN  ...
# 4  Donwald Pressly         440         NaN        NaN           NaN  ...
#
#                                         Article_Text  \
# 0  AS WITH many a passion, one\'s earliest beginn...
# 1  Instead, business organisations, municipalitie...
# 2  Today\'s meeting of the Brazil, South Africa, ...
# 3  RECYCLED effluent from Gauteng will be used to...
# 4  Public enterprises committee members were this...
#
#                                     City  State  \
# 0                CAPE TOWN, SOUTH AFRICA    NaN
# 1                                    NaN    NaN
# 2  COPENHAGEN, DENMARK; NEW DELHI, INDIA  EARTH
# 3                                    NaN    NaN
# 4                                    NaN    NaN
#
#                                              Country  \
# 0                                       SOUTH AFRICA
# 1                      SOUTH AFRICA; SOUTHERN AFRICA
# 2  SOUTH AFRICA; INDIA; AFRICA; BRAZIL; CHINA; UN...
# 3                                       SOUTH AFRICA
# 4                                       SOUTH AFRICA
#
#                              News Outlet  \
# 0  The Sunday Independent (South Africa)
# 1  The Sunday Independent (South Africa)
# 2  The Sunday Independent (South Africa)
# 3  The Sunday Independent (South Africa)
# 4  The Sunday Independent (South Africa)
#
#                                  Word Count  ArticleCount  frequency version  \
# 0                   LIFE; Pg. 30, 1860words           368     weekly   print
# 1  BUSINESS REPORT WEEKEND; Pg. 1, 700words           368     weekly   print
# 2                           NEWS, 1768words           368     weekly   print
# 3                    NEWS; Pg. 10, 867words           368     weekly   print
# 4  BUSINESS REPORT WEEKEND; Pg. 1, 440words           368     weekly   print
#
#                           Dominant Topic
# 0            Stopwords/False Positives 2
# 1                           Eskom crisis
# 2  Transition politics & climate finance
# 3                   Anti-mining activism
# 4                     Electricity crisis
#
# [5 rows x 52 columns]
# Unique topics in the DataFrame: ['Stopwords/False Positives 2' 'Eskom crisis'
#  'Transition politics & climate finance' 'Anti-mining activism'
#  'Electricity crisis' 'Daily political business' 'Coal transport'
#  'Climate change impact' 'Coal trade relations'
#  'Energy policies & renewables' 'Mining market dynamics'
#  'Safety & illegal activities' 'State intervention in mining'
#  'Indian South Africans history' 'State capture & corruption'
#  'Oil & gas alternatives' 'Coal labor issues' 'Mining investments'
#  'Air pollution' 'Stopwords/False Positives 1']
# Filtered DataFrame has 1745 rows after filtering by topics.
# Subset DataFrame has 1745 rows.
# Collected 5035 sentences containing the word 'coal'.
# Predicting NER with spaCy: 100%|██████████| 5035/5035 [01:16<00:00, 66.10it/s]
#                                              Sentence  \
# 0   They contrast the ineffectual "pork-laden" leg...
# 1   The major bills are now being pushed by John K...
# 2   The boiler deals give the ruling party a multi...
# 3   In reality, cuts promised in the Long-Term Mit...
# 4   As the Eskom tariff hearings organised by the ...
# 5   Environment and social justice activists are c...
# 6   The decision to grant the loan came in the wak...
# 7   Hundreds of African and global NGO\'s, academi...
# 8   The factories recycle and use gas instead of c...
# 9   The government\'s nuclear proposals come with ...
# 10  Very little public consultation took place bef...
# 11  Magubane indicated that the R400bn being spent...
# 12  To compare the PBMR numbers with the latest co...
# 13  These numbers indicate PBMR\'s reactor is some...
# 14  South Africa has pledged to curtail its compar...
# 15  "But it may also be more difficult for the gov...
# 16  South Africa is building two massive coal-fire...
# 17  Because of the CDM officials\' increasing embr...
# 18  But immediately disproving any intent to suppo...
# 19  But the plan was to build a R20 billion smelte...
#
#                            Dominant Topic  \
# 0   Transition politics & climate finance
# 1   Transition politics & climate finance
# 2   Transition politics & climate finance
# 3   Transition politics & climate finance
# 4   Transition politics & climate finance
# 5   Transition politics & climate finance
# 6   Transition politics & climate finance
# 7   Transition politics & climate finance
# 8                   Climate change impact
# 9            Energy policies & renewables
# 10           Energy policies & renewables
# 11           Energy policies & renewables
# 12           Energy policies & renewables
# 13           Energy policies & renewables
# 14  Transition politics & climate finance
# 15  Transition politics & climate finance
# 16  Transition politics & climate finance
# 17  Transition politics & climate finance
# 18  Transition politics & climate finance
# 19  Transition politics & climate finance
#
#                                              Entities
# 0   [(the Environmental Protection Agency\'s, ORG)...
# 1   [(John Kerry, PERSON), (Joseph Lieberman, PERS...
# 2                                                  []
# 3   [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 4                        [(Eskom, ORG), (Eskom, ORG)]
# 5                             [(the World Bank, ORG)]
# 6                                                  []
# 7                  [(the Environmental Justice, ORG)]
# 8                                                  []
# 9                                  [(R400bn, PERSON)]
# 10                                     [(Eskom, ORG)]
# 11                                                 []
# 12                                      [(PBMR, ORG)]
# 13                                                 []
# 14                                                 []
# 15                                       [(it\, ORG)]
# 16                                                 []
# 17  [(CDM, ORG), (the Global Forest Coalition, ORG...
# 18                       [(Van Schalkwyk\'s, PERSON)]
# 19                                                 []

# %%
# Create a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in topics_of_interest}

for sentence, topic, entities in predictions:
    entities_by_topic[topic].extend(entities)

# Compute frequency of each entity per topic
summary_statistics = {}

for topic, entities in entities_by_topic.items():
    counter = Counter(entities)
    summary_statistics[topic] = counter.most_common()

# Create a DataFrame to display the summary statistics
summary_data = []

for topic, entity_list in summary_statistics.items():
    for (entity_text, entity_type), count in entity_list:
        summary_data.append([topic, entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Topic', 'Entity', 'Type', 'Count'])

# Export the DataFrame as a CSV file
df_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_spacy_summary_statistics.csv', index=False)

# Display the DataFrame
print(df_summary.head(20))
# Out:
#                                     Topic                       Entity  \
# 0   Transition politics & climate finance                        Eskom
# 1   Transition politics & climate finance                           SA
# 2   Transition politics & climate finance                     Mantashe
# 3   Transition politics & climate finance                   Mpumalanga
# 4   Transition politics & climate finance                       Eskom\
# 5   Transition politics & climate finance                       Komati
# 6   Transition politics & climate finance               the World Bank
# 7   Transition politics & climate finance                       Sasol\
# 8   Transition politics & climate finance                           EU
# 9   Transition politics & climate finance                         Coal
# 10  Transition politics & climate finance                   World Bank
# 11  Transition politics & climate finance                Standard Bank
# 12  Transition politics & climate finance                          G20
# 13  Transition politics & climate finance                       Kusile
# 14  Transition politics & climate finance               Gwede Mantashe
# 15  Transition politics & climate finance                          ANC
# 16  Transition politics & climate finance  first onThe Mail & Guardian
# 17  Transition politics & climate finance              Cyril Ramaphosa
# 18  Transition politics & climate finance                      Africa\
# 19  Transition politics & climate finance               Barbara Creecy
#
#       Type  Count
# 0      ORG     84
# 1      ORG     75
# 2   PERSON     31
# 3   PERSON     26
# 4      ORG     21
# 5      ORG     20
# 6      ORG     18
# 7   PERSON     15
# 8      ORG     15
# 9   PERSON     14
# 10     ORG     12
# 11     ORG     12
# 12     ORG     12
# 13     ORG      9
# 14  PERSON      8
# 15     ORG      8
# 16     ORG      8
# 17  PERSON      7
# 18     ORG      7
# 19  PERSON      7

# %% [markdown]
# ## now same but with sentences before and after coal sentence included

# %%
import pandas as pd
import nltk
from tqdm import tqdm
import spacy
from collections import Counter

nltk.download('punkt')

# Read the CSV file
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/coal_data_filtered_nodup_cleaned3.csv'
df = pd.read_csv(path_to_csv)

# Load the file with the info on top topic per document
path_to_df_top = '/content/drive/MyDrive/Colab Notebooks/topic_model_3_k20_srl_2.csv'
df_top = pd.read_csv(path_to_df_top)

# Merge the datasets based on id column
df = df.merge(df_top, left_on='Unnamed: 0.1', right_on='Unnamed: 0.1', how='left')

# Extract Year and Month from the Date column
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

print("Merged DataFrame:")
print(df.head())

# List unique topics in the DataFrame
unique_topics = df['Dominant Topic'].unique()
print("Unique topics in the DataFrame:", unique_topics)

# Filter out the topics of no interest
topics_of_no_interest = ["Mining market dynamics", "Stopwords/False Positives 1", "Stopwords/False Positives 2", "Indian South Africans history", "Coal transport"]
df = df[~df['Dominant Topic'].isin(topics_of_no_interest)] # is not it

print(f"Filtered DataFrame has {len(df)} rows after filtering by topics.")

# Extract necessary columns
df_subset = df[['Article_Text', 'Dominant Topic', 'Year', 'Month']]

print(f"Subset DataFrame has {len(df_subset)} rows.")

# Initialize an empty list to store sentences and topics
data = []

# Function to truncate sentences
def truncate_sentence(sentence, max_length=50):
    words = sentence.split()
    if len(words) > max_length:
        sentence = ' '.join(words[:max_length])
    return sentence

# Iterate over the text of the articles
for index, row in df_subset.iterrows():
    text = row['Article_Text']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    # Split the text into sentences using NLTK's sent_tokenize function
    text_sentences = nltk.sent_tokenize(text)
    # Check each sentence for the presence of the word "coal"
    for i, sentence in enumerate(text_sentences):
        # Convert the sentence to lowercase for case-insensitive matching
        sentence_lower = sentence.lower()
        # Check if the sentence contains the word "coal"
        if "coal" in sentence_lower:
            # Collect the sentence before, the sentence with "coal", and the sentence after
            before = text_sentences[i-1] if i > 0 else ""
            after = text_sentences[i+1] if i < len(text_sentences) - 1 else ""
            sentences_to_add = [before, sentence, after]
            for sent in sentences_to_add:
                if sent:  # Only add non-empty sentences
                    truncated_sentence = truncate_sentence(sent)
                    data.append((truncated_sentence, topic, year, month))

print(f"Collected {len(data)} sentences containing the word 'coal' and their surrounding context.")

# Load the pre-trained spaCy model for NER
nlp = spacy.load('en_core_web_sm')

# Function to predict entities using spaCy
def predict_ner_spacy(data):
    predictions = []
    for sentence, topic, year, month in tqdm(data, desc="Predicting NER with spaCy"):
        doc = nlp(sentence)
        entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['PERSON', 'ORG', 'LOC']]
        predictions.append((sentence, topic, year, month, entities))
    return predictions

# Run prediction
predictions = predict_ner_spacy(data)

# Create an empty list to store the data for the DataFrame
df_data = []

for sentence, topic, year, month, entities in predictions:
    df_data.append([sentence, topic, year, month, entities])

# Create a DataFrame from the data list
df_ner = pd.DataFrame(df_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entities'])

# Export the DataFrame as a CSV file
df_ner.to_csv('/mnt/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy3_top_topic.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))

# Create a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in topics_of_interest}

for sentence, topic, year, month, entities in predictions:
    entities_by_topic[topic].extend(entities)

# Compute frequency of each entity per topic
summary_statistics = {}

for topic, entities in entities_by_topic.items():
    counter = Counter(entities)
    summary_statistics[topic] = counter.most_common()

# Create a DataFrame to display the summary statistics
summary_data = []

for topic, entity_list in summary_statistics.items():
    for (entity_text, entity_type), count in entity_list:
        summary_data.append([topic, entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Topic', 'Entity', 'Type', 'Count'])

# Export the DataFrame as a CSV file
df_summary.to_csv('/mnt/drive/MyDrive/Colab Notebooks/ner_spacy3_summary_statistics.csv', index=False)

# Display the DataFrame
print(df_summary.head(20))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Merged DataFrame:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2         168
# 1             3         261
# 2             4         263
# 3             5         360
# 4             6         361
#
#                                         Jurisdiction  Location ContentType  \
# 0                                      International       NaN        News
# 1                                      International       NaN        News
# 2  U.S. Federal; International; Massachusetts; Wa...       NaN        News
# 3                                      International       NaN        News
# 4                                      International       NaN        News
#
#             Byline  WordLength  WebNewsUrl  Geography  NegativeNews  ...  \
# 0              NaN        1860         NaN        NaN           NaN  ...
# 1     Ingi Salgado         700         NaN        NaN           NaN  ...
# 2     Patrick Bond        1768         NaN        NaN           NaN  ...
# 3  Eleanor Momberg         867         NaN        NaN           NaN  ...
# 4  Donwald Pressly         440         NaN        NaN           NaN  ...
#
#    State                                            Country  \
# 0    NaN                                       SOUTH AFRICA
# 1    NaN                      SOUTH AFRICA; SOUTHERN AFRICA
# 2  EARTH  SOUTH AFRICA; INDIA; AFRICA; BRAZIL; CHINA; UN...
# 3    NaN                                       SOUTH AFRICA
# 4    NaN                                       SOUTH AFRICA
#
#                              News Outlet  \
# 0  The Sunday Independent (South Africa)
# 1  The Sunday Independent (South Africa)
# 2  The Sunday Independent (South Africa)
# 3  The Sunday Independent (South Africa)
# 4  The Sunday Independent (South Africa)
#
#                                  Word Count ArticleCount  frequency  version  \
# 0                   LIFE; Pg. 30, 1860words          368     weekly    print
# 1  BUSINESS REPORT WEEKEND; Pg. 1, 700words          368     weekly    print
# 2                           NEWS, 1768words          368     weekly    print
# 3                    NEWS; Pg. 10, 867words          368     weekly    print
# 4  BUSINESS REPORT WEEKEND; Pg. 1, 440words          368     weekly    print
#
#                           Dominant Topic  Year  Month
# 0            Stopwords/False Positives 2  2010      1
# 1                           Eskom crisis  2010      1
# 2  Transition politics & climate finance  2010      1
# 3                   Anti-mining activism  2010      1
# 4                     Electricity crisis  2010      1
#
# [5 rows x 54 columns]
# Unique topics in the DataFrame: ['Stopwords/False Positives 2' 'Eskom crisis'
#  'Transition politics & climate finance' 'Anti-mining activism'
#  'Electricity crisis' 'Daily political business' 'Coal transport'
#  'Climate change impact' 'Coal trade relations'
#  'Energy policies & renewables' 'Mining market dynamics'
#  'Safety & illegal activities' 'State intervention in mining'
#  'Indian South Africans history' 'State capture & corruption'
#  'Oil & gas alternatives' 'Coal labor issues' 'Mining investments'
#  'Air pollution' 'Stopwords/False Positives 1']
# Filtered DataFrame has 6160 rows after filtering by topics.
# Subset DataFrame has 6160 rows.
# Collected 49171 sentences containing the word 'coal' and their surrounding context.
# Predicting NER with spaCy: 100%|██████████| 49171/49171 [10:49<00:00, 75.75it/s]
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-3445c5364f67> in <cell line: 103>()
#     101
#     102 # Export the DataFrame as a CSV file
# --> 103 df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy3_top_topic.csv', index=False)
#     104
#     105 # Display the DataFrame
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3770         )
#    3771
# -> 3772         return DataFrameRenderer(formatter).to_csv(
#    3773             path_or_buf,
#    3774             lineterminator=lineterminator,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1184             formatter=self.fmt,
#    1185         )
# -> 1186         csv_formatter.save()
#    1187
#    1188         if created_buffer:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/formats/csvs.py in save(self)
#     238         """
#     239         # apply compression and byte/text conversion
# --> 240         with get_handle(
#     241             self.filepath_or_buffer,
#     242             self.mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     735     # Only for write methods
#     736     if "r" not in mode and is_path:
# --> 737         check_parent_directory(str(handle))
#     738
#     739     if compression:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in check_parent_directory(path)
#     598     parent = Path(path).parent
#     599     if not parent.is_dir():
# --> 600         raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#     601
#     602
#
# OSError: Cannot save file into a non-existent directory: '/content/drive/MyDrive/Colab Notebooks'

# %%
# Export the DataFrame as a CSV file
df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy3_top_topic.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))

# Create a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in topics_of_no_interest}

for sentence, topic, year, month, entities in predictions:
    entities_by_topic[topic].extend(entities)

# Compute frequency of each entity per topic
summary_statistics = {}

for topic, entities in entities_by_topic.items():
    counter = Counter(entities)
    summary_statistics[topic] = counter.most_common()

# Create a DataFrame to display the summary statistics
summary_data = []

for topic, entity_list in summary_statistics.items():
    for (entity_text, entity_type), count in entity_list:
        summary_data.append([topic, entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Topic', 'Entity', 'Type', 'Count'])

# Export the DataFrame as a CSV file
df_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_spacy3_summary_statistics.csv', index=False)

# Display the DataFrame
print(df_summary.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   "We\'re confident this will prove more cost-ef...
# 5   There was widespread support for Britton\'s pr...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  It is also based on "cap and trade" in which p...
# 12  The problem of relying upon these actors to sa...
# 13  The boiler deals give the ruling party a multi...
# 14  If Zuma aims, therefore, to persuade the world...
# 15  The cuts promised by Sonjica just before Copen...
# 16  In reality, cuts promised in the Long-Term Mit...
# 17  As the Eskom tariff hearings organised by the ...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                              Entities
# 0         [(the Family and Marriage Society SA, ORG)]
# 1                                                  []
# 2   [(the Southern African Faith Communities Envir...
# 3   [(the Southern African Faith Communities Envir...
# 4                             [(Sue Britton, PERSON)]
# 5                                   [(Britton\, ORG)]
# 6                                   [(Congress, ORG)]
# 7   [(the Environmental Protection Agency\'s, ORG)...
# 8                                        [(EPA, ORG)]
# 9                                     [(Senate, ORG)]
# 10  [(John Kerry, PERSON), (Joseph Lieberman, PERS...
# 11                                                 []
# 12                         [(ANC, ORG), (House, ORG)]
# 13                                                 []
# 14                                   [(Zuma, PERSON)]
# 15                                [(Copenhagen, ORG)]
# 16  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 17                       [(Eskom, ORG), (Eskom, ORG)]
# 18  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 19                       [(Eskom, ORG), (Eskom, ORG)]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-bcb79105e2e9> in <cell line: 8>()
#       6
#       7 # Create a dictionary to store entities by topic
# ----> 8 entities_by_topic = {topic: [] for topic in topics_of_interest}
#       9
#      10 for sentence, topic, year, month, entities in predictions:
#
# NameError: name 'topics_of_interest' is not defined

# %%
# Export the DataFrame as a CSV file
df_ner.to_csv('/mnt/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy2_top_topic.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))
# Create a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in topics_of_interest}

for sentence, topic, entities in predictions:
    entities_by_topic[topic].extend(entities)

# Compute frequency of each entity per topic
summary_statistics = {}

for topic, entities in entities_by_topic.items():
    counter = Counter(entities)
    summary_statistics[topic] = counter.most_common()

# Create a DataFrame to display the summary statistics
summary_data = []

for topic, entity_list in summary_statistics.items():
    for (entity_text, entity_type), count in entity_list:
        summary_data.append([topic, entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Topic', 'Entity', 'Type', 'Count'])

# Export the DataFrame as a CSV file
df_summary.to_csv('/mnt/drive/MyDrive/Colab Notebooks/ner_spacy2_summary_statistics.csv', index=False)

# Display the DataFrame
print(df_summary.head(20))
# Out:
#                                              Sentence  \
# 0   Given the power relations in Congress, this is...
# 1   They contrast the ineffectual "pork-laden" leg...
# 2   In December, the EPA issued an "endangerment" ...
# 3   Hence halting the legislation in the Senate is...
# 4   The major bills are now being pushed by John K...
# 5   It is also based on "cap and trade" in which p...
# 6   The problem of relying upon these actors to sa...
# 7   The boiler deals give the ruling party a multi...
# 8   If Zuma aims, therefore, to persuade the world...
# 9   The cuts promised by Sonjica just before Copen...
# 10  In reality, cuts promised in the Long-Term Mit...
# 11  As the Eskom tariff hearings organised by the ...
# 12  In reality, cuts promised in the Long-Term Mit...
# 13  As the Eskom tariff hearings organised by the ...
# 14  Yet the purpose of the new build programme is ...
# 15  Environment and social justice activists are c...
# 16  The decision to grant the loan came in the wak...
# 17  Environment and social justice activists are c...
# 18  The decision to grant the loan came in the wak...
# 19  Hundreds of African and global NGO\'s, academi...
#
#                            Dominant Topic  \
# 0   Transition politics & climate finance
# 1   Transition politics & climate finance
# 2   Transition politics & climate finance
# 3   Transition politics & climate finance
# 4   Transition politics & climate finance
# 5   Transition politics & climate finance
# 6   Transition politics & climate finance
# 7   Transition politics & climate finance
# 8   Transition politics & climate finance
# 9   Transition politics & climate finance
# 10  Transition politics & climate finance
# 11  Transition politics & climate finance
# 12  Transition politics & climate finance
# 13  Transition politics & climate finance
# 14  Transition politics & climate finance
# 15  Transition politics & climate finance
# 16  Transition politics & climate finance
# 17  Transition politics & climate finance
# 18  Transition politics & climate finance
# 19  Transition politics & climate finance
#
#                                              Entities
# 0                                   [(Congress, ORG)]
# 1   [(the Environmental Protection Agency\'s, ORG)...
# 2                                        [(EPA, ORG)]
# 3                                     [(Senate, ORG)]
# 4   [(John Kerry, PERSON), (Joseph Lieberman, PERS...
# 5                                                  []
# 6                          [(ANC, ORG), (House, ORG)]
# 7                                                  []
# 8                                    [(Zuma, PERSON)]
# 9                                 [(Copenhagen, ORG)]
# 10  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 11                       [(Eskom, ORG), (Eskom, ORG)]
# 12  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 13                       [(Eskom, ORG), (Eskom, ORG)]
# 14                                     [(Eskom, ORG)]
# 15                            [(the World Bank, ORG)]
# 16                                                 []
# 17                            [(the World Bank, ORG)]
# 18                                                 []
# 19                 [(the Environmental Justice, ORG)]
#                                     Topic           Entity    Type  Count
# 0   Transition politics & climate finance            Eskom     ORG    206
# 1   Transition politics & climate finance               SA     ORG    178
# 2   Transition politics & climate finance         Mantashe  PERSON     83
# 3   Transition politics & climate finance       Mpumalanga  PERSON     56
# 4   Transition politics & climate finance           Komati     ORG     55
# 5   Transition politics & climate finance   the World Bank     ORG     43
# 6   Transition politics & climate finance           Sasol\  PERSON     41
# 7   Transition politics & climate finance               EU     ORG     40
# 8   Transition politics & climate finance           Eskom\     ORG     38
# 9   Transition politics & climate finance       World Bank     ORG     34
# 10  Transition politics & climate finance              G20     ORG     30
# 11  Transition politics & climate finance             Coal  PERSON     28
# 12  Transition politics & climate finance    Standard Bank     ORG     27
# 13  Transition politics & climate finance              ANC     ORG     26
# 14  Transition politics & climate finance  Cyril Ramaphosa  PERSON     26
# 15  Transition politics & climate finance        Ramaphosa  PERSON     23
# 16  Transition politics & climate finance               UN     ORG     22
# 17  Transition politics & climate finance   Gwede Mantashe  PERSON     21
# 18  Transition politics & climate finance           Durban     ORG     20
# 19  Transition politics & climate finance           Kusile     ORG     20

# %% [markdown]
# # Here is code for training the model myself. To much effort maybe
# -> Adapt following this approach: https://medium.com/@mjghadge9007/building-your-own-custom-named-entity-recognition-ner-model-with-spacy-v3-a-step-by-step-guide-15c7dcb1c416

# %%
#Should I train the model to fit better to south africa coal discourse? too much work...

import spacy
from spacy.training.example import Example
from spacy.training import offsets_to_biluo_tags
from spacy.tokens import DocBin
import os

# Load the pre-trained model
nlp = spacy.load('en_core_web_sm')

# Get the NER component
ner = nlp.get_pipe("ner")

# Add new labels to the NER component
ner.add_label("PERSON")
ner.add_label("ORG")
ner.add_label("LOC")

# Prepare the training data
TRAIN_DATA = [
    ("The coal project by Eskom in South Africa is under review.", {"entities": [(18, 23, "ORG"), (27, 39, "LOC")]}),
    ("Gwede Mantashe announced new regulations.", {"entities": [(0, 15, "PERSON")]}),
    ("President Cyril Ramaphosa on Tuesday received the Just Energy Transition (JET) framework.", {"entities": [(0, 26, "PERSON")]}),
    ("The framework, compiled by the Presidential Climate Commission, could assist in unlocking a $8.5 billion or R136.2 billion climate partnership.", {"entities": [(32, 63, "PERSON")]}),
    ("Creecy said South Africa would use COP27 as a platform to call for greater support for just transitions in Africa as a whole, starting with energy transitions.", {"entities": [(0, 7, "PERSON")]}),

    # Add more examples here
]

# Convert the training data to Spacy's format
doc_bin = DocBin()
for text, annotations in TRAIN_DATA:
    doc = nlp.make_doc(text)
    ents = annotations.get("entities")
    tags = offsets_to_biluo_tags(doc, ents)
    example = Example.from_dict(doc, {"entities": ents})
    doc_bin.add(doc)

# Disable other pipes during training
pipe_exceptions = ["ner"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# Start the training
with nlp.disable_pipes(*unaffected_pipes):
    optimizer = nlp.resume_training()
    for i in range(10):  # Number of iterations
        print(f"Iteration {i+1}")
        losses = {}
        for text, annotations in TRAIN_DATA:
            example = Example.from_dict(nlp.make_doc(text), annotations)
            nlp.update([example], drop=0.35, losses=losses)
        print(losses)

# Save the fine-tuned model
output_dir = "/content/drive/MyDrive/Colab Notebooks/fine_tuned_model"
os.makedirs(output_dir, exist_ok=True)  # Create the directory if it doesn't exist
nlp.to_disk(output_dir)

# Load and test the fine-tuned model
nlp = spacy.load(output_dir)
doc = nlp("Eskom is planning a new project in South Africa.")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Iteration 1
# {'ner': 11.195735443487964}
# Iteration 2
# {'ner': 9.044242955125483}
# Iteration 3
# {'ner': 1.555782224395195}
# Iteration 4
# {'ner': 1.2956786661897208}
# Iteration 5
# {'ner': 0.015279359113505279}
# Iteration 6
# {'ner': 0.13250828181551302}
# Iteration 7
# {'ner': 9.232916662523946e-05}
# Iteration 8
# {'ner': 0.08662877274268363}
# Iteration 9
# {'ner': 0.006387259315941214}
# Iteration 10
# {'ner': 1.3389363763387474e-06}

# %%
#integrate into existing model
import pandas as pd
import nltk
from tqdm import tqdm
import spacy
from collections import Counter
nltk.download('punkt')
# Read the CSV file
path_to_csv = '/mnt/drive/MyDrive/Colab Notebooks/coal_data_filtered_nodup_cleaned3.csv'
df = pd.read_csv(path_to_csv)

# Load the file with the info on top topic per document
path_to_df_top = '/mnt/drive/MyDrive/Colab Notebooks/topic_model_3_k20_srl_2.csv'
df_top = pd.read_csv(path_to_df_top)


# Merge the datasets based on id column
df = df.merge(df_top, left_on='Unnamed: 0.1', right_on='Unnamed: 0.1', how='left')

print("Merged DataFrame:")
print(df.head())

# List unique topics in the DataFrame
unique_topics = df['Dominant Topic'].unique()
print("Unique topics in the DataFrame:", unique_topics)

# Filter out the topics of interest
topics_of_interest = ["Transition politics & climate finance", "Energy policies & renewables", "Oil & gas alternatives", "Climate change impact", "Coal labor issues"]
df = df[df['Dominant Topic'].isin(topics_of_interest)]

print(f"Filtered DataFrame has {len(df)} rows after filtering by topics.")

# Extract necessary columns
df_subset = df[['Article_Text', 'Dominant Topic']]

print(f"Subset DataFrame has {len(df_subset)} rows.")
data = []

# Function to truncate sentences
def truncate_sentence(sentence, max_length=50):
    words = sentence.split()
    if len(words) > max_length:
        sentence = ' '.join(words[:max_length])
    return sentence

# Iterate over the text of the articles
for index, row in df_subset.iterrows():
    text = row['Article_Text']
    topic = row['Dominant Topic']
    # Split the text into sentences using NLTK's sent_tokenize function
    text_sentences = nltk.sent_tokenize(text)
    # Check each sentence for the presence of the word "coal"
    for sentence in text_sentences:
        # Convert the sentence to lowercase for case-insensitive matching
        sentence_lower = sentence.lower()
        # Check if the sentence contains the word "coal"
        if "coal" in sentence_lower:
            truncated_sentence = truncate_sentence(sentence)
            data.append((truncated_sentence, topic))

print(f"Collected {len(data)} sentences containing the word 'coal'.")

# Load the fine-tuned model
nlp = spacy.load('/content/drive/MyDrive/Colab Notebooks/fine_tuned_model')

# Function to predict entities using the fine-tuned spaCy model
def predict_ner_spacy(data):
    predictions = []
    for sentence, topic in tqdm(data, desc="Predicting NER with spaCy"):
        doc = nlp(sentence)
        entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['PERSON', 'ORG', 'LOC']]
        predictions.append((sentence, topic, entities))
    return predictions

# Run prediction
predictions = predict_ner_spacy(data)

# Create a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in topics_of_interest}

for sentence, topic, entities in predictions:
    entities_by_topic[topic].extend(entities)

# Compute frequency of each entity per topic
summary_statistics = {}

for topic, entities in entities_by_topic.items():
    counter = Counter(entities)
    summary_statistics[topic] = counter.most_common()

# Create a DataFrame to display the summary statistics
summary_data = []

for topic, entity_list in summary_statistics.items():
    for (entity_text, entity_type), count in entity_list:
        summary_data.append([topic, entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Topic', 'Entity', 'Type', 'Count'])

# Export the DataFrame as a CSV file
df_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_summary2_statistics.csv', index=False)

# Display the DataFrame
print(df_summary.head(20))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Merged DataFrame:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2         168
# 1             3         261
# 2             4         263
# 3             5         360
# 4             6         361
#
#                                         Jurisdiction  Location ContentType  \
# 0                                      International       NaN        News
# 1                                      International       NaN        News
# 2  U.S. Federal; International; Massachusetts; Wa...       NaN        News
# 3                                      International       NaN        News
# 4                                      International       NaN        News
#
#             Byline  WordLength  WebNewsUrl  Geography  NegativeNews  ...  \
# 0              NaN        1860         NaN        NaN           NaN  ...
# 1     Ingi Salgado         700         NaN        NaN           NaN  ...
# 2     Patrick Bond        1768         NaN        NaN           NaN  ...
# 3  Eleanor Momberg         867         NaN        NaN           NaN  ...
# 4  Donwald Pressly         440         NaN        NaN           NaN  ...
#
#                                         Article_Text  \
# 0  AS WITH many a passion, one\'s earliest beginn...
# 1  Instead, business organisations, municipalitie...
# 2  Today\'s meeting of the Brazil, South Africa, ...
# 3  RECYCLED effluent from Gauteng will be used to...
# 4  Public enterprises committee members were this...
#
#                                     City  State  \
# 0                CAPE TOWN, SOUTH AFRICA    NaN
# 1                                    NaN    NaN
# 2  COPENHAGEN, DENMARK; NEW DELHI, INDIA  EARTH
# 3                                    NaN    NaN
# 4                                    NaN    NaN
#
#                                              Country  \
# 0                                       SOUTH AFRICA
# 1                      SOUTH AFRICA; SOUTHERN AFRICA
# 2  SOUTH AFRICA; INDIA; AFRICA; BRAZIL; CHINA; UN...
# 3                                       SOUTH AFRICA
# 4                                       SOUTH AFRICA
#
#                              News Outlet  \
# 0  The Sunday Independent (South Africa)
# 1  The Sunday Independent (South Africa)
# 2  The Sunday Independent (South Africa)
# 3  The Sunday Independent (South Africa)
# 4  The Sunday Independent (South Africa)
#
#                                  Word Count  ArticleCount  frequency version  \
# 0                   LIFE; Pg. 30, 1860words           368     weekly   print
# 1  BUSINESS REPORT WEEKEND; Pg. 1, 700words           368     weekly   print
# 2                           NEWS, 1768words           368     weekly   print
# 3                    NEWS; Pg. 10, 867words           368     weekly   print
# 4  BUSINESS REPORT WEEKEND; Pg. 1, 440words           368     weekly   print
#
#                           Dominant Topic
# 0            Stopwords/False Positives 2
# 1                           Eskom crisis
# 2  Transition politics & climate finance
# 3                   Anti-mining activism
# 4                     Electricity crisis
#
# [5 rows x 52 columns]
# Unique topics in the DataFrame: ['Stopwords/False Positives 2' 'Eskom crisis'
#  'Transition politics & climate finance' 'Anti-mining activism'
#  'Electricity crisis' 'Daily political business' 'Coal transport'
#  'Climate change impact' 'Coal trade relations'
#  'Energy policies & renewables' 'Mining market dynamics'
#  'Safety & illegal activities' 'State intervention in mining'
#  'Indian South Africans history' 'State capture & corruption'
#  'Oil & gas alternatives' 'Coal labor issues' 'Mining investments'
#  'Air pollution' 'Stopwords/False Positives 1']
# Filtered DataFrame has 1745 rows after filtering by topics.
# Subset DataFrame has 1745 rows.
# Collected 5035 sentences containing the word 'coal'.
# Predicting NER with spaCy: 100%|██████████| 5035/5035 [01:37<00:00, 51.48it/s]
#                                     Topic                 Entity    Type  \
# 0   Transition politics & climate finance         Gwede Mantashe  PERSON
# 1   Transition politics & climate finance        Cyril Ramaphosa  PERSON
# 2   Transition politics & climate finance         Barbara Creecy  PERSON
# 3   Transition politics & climate finance             Bobby Peek  PERSON
# 4   Transition politics & climate finance                     UN     ORG
# 5   Transition politics & climate finance               Mantashe  PERSON
# 6   Transition politics & climate finance        Buyelwa Sonjica  PERSON
# 7   Transition politics & climate finance            Simon Crean  PERSON
# 8   Transition politics & climate finance         Sarwat Hussain  PERSON
# 9   Transition politics & climate finance         Pravin Gordhan  PERSON
# 10  Transition politics & climate finance          Melita Steele  PERSON
# 11  Transition politics & climate finance                 Steele  PERSON
# 12  Transition politics & climate finance  Kgosientsho Ramokgopa  PERSON
# 13  Transition politics & climate finance        Robert Zoellick  PERSON
# 14  Transition politics & climate finance       Enoch Godongwana  PERSON
# 15  Transition politics & climate finance                 Sylvia  PERSON
# 16  Transition politics & climate finance                  Gwede  PERSON
# 17  Transition politics & climate finance          Chris Yelland  PERSON
# 18  Transition politics & climate finance       Mtshweni-Tsipane     ORG
# 19  Transition politics & climate finance             John Kerry  PERSON
#
#     Count
# 0       8
# 1       7
# 2       6
# 3       5
# 4       4
# 5       4
# 6       2
# 7       2
# 8       2
# 9       2
# 10      2
# 11      2
# 12      2
# 13      2
# 14      2
# 15      2
# 16      2
# 17      2
# 18      2
# 19      1

# %%
df_summary.to_csv('/mnt/drive/MyDrive/Colab Notebooks/ner_summary2_statistics.csv', index=False)

# %% [markdown]
#   ## Uploading the dataframe to to get correct represenentation for sentiment anaylsis.

# %%
# This is displaying Person and ORG as seperate columns

path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy3_top_topic.csv'
df_ner = pd.read_csv(path_to_csv)


# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize columns for Persons and Organizations
df_ner['Persons'] = df_ner['Entities'].apply(lambda entities: [entity[0] for entity in entities if entity[1] == 'PERSON'])
df_ner['Organizations'] = df_ner['Entities'].apply(lambda entities: [entity[0] for entity in entities if entity[1] == 'ORG'])

df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_1.csv', index=False)

# Display the DataFrame with the new columns
print(df_ner.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   "We\'re confident this will prove more cost-ef...
# 5   There was widespread support for Britton\'s pr...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  It is also based on "cap and trade" in which p...
# 12  The problem of relying upon these actors to sa...
# 13  The boiler deals give the ruling party a multi...
# 14  If Zuma aims, therefore, to persuade the world...
# 15  The cuts promised by Sonjica just before Copen...
# 16  In reality, cuts promised in the Long-Term Mit...
# 17  As the Eskom tariff hearings organised by the ...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                              Entities  \
# 0         [(the Family and Marriage Society SA, ORG)]
# 1                                                  []
# 2   [(the Southern African Faith Communities Envir...
# 3   [(the Southern African Faith Communities Envir...
# 4                             [(Sue Britton, PERSON)]
# 5                                   [(Britton\, ORG)]
# 6                                   [(Congress, ORG)]
# 7   [(the Environmental Protection Agency\'s, ORG)...
# 8                                        [(EPA, ORG)]
# 9                                     [(Senate, ORG)]
# 10  [(John Kerry, PERSON), (Joseph Lieberman, PERS...
# 11                                                 []
# 12                         [(ANC, ORG), (House, ORG)]
# 13                                                 []
# 14                                   [(Zuma, PERSON)]
# 15                                [(Copenhagen, ORG)]
# 16  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 17                       [(Eskom, ORG), (Eskom, ORG)]
# 18  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 19                       [(Eskom, ORG), (Eskom, ORG)]
#
#                                            Persons  \
# 0                                               []
# 1                                               []
# 2                                               []
# 3                                               []
# 4                                    [Sue Britton]
# 5                                               []
# 6                                               []
# 7                                               []
# 8                                               []
# 9                                               []
# 10  [John Kerry, Joseph Lieberman, Lindsay Graham]
# 11                                              []
# 12                                              []
# 13                                              []
# 14                                          [Zuma]
# 15                                              []
# 16                                         [Sasol]
# 17                                              []
# 18                                         [Sasol]
# 19                                              []
#
#                                         Organizations
# 0                [the Family and Marriage Society SA]
# 1                                                  []
# 2   [the Southern African Faith Communities Enviro...
# 3   [the Southern African Faith Communities Enviro...
# 4                                                  []
# 5                                          [Britton\]
# 6                                          [Congress]
# 7   [the Environmental Protection Agency\'s, Chevr...
# 8                                               [EPA]
# 9                                            [Senate]
# 10                                                 []
# 11                                                 []
# 12                                       [ANC, House]
# 13                                                 []
# 14                                                 []
# 15                                       [Copenhagen]
# 16                [the Long-Term Mitigation Scenario]
# 17                                     [Eskom, Eskom]
# 18                [the Long-Term Mitigation Scenario]
# 19                                     [Eskom, Eskom]

# %%
# This is displaying a new row for each identified entity (so if >1 entity in same sentence, same sentence over >1 rows )

# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy3_top_topic.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]
        expanded_data.append([sentence, topic, year, month, entity_name, entity_type])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Actor', 'Type'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_2.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Many organisations, including the Southern Afr...
# 2   Many organisations, including the Southern Afr...
# 3   "We\'re confident this will prove more cost-ef...
# 4   There was widespread support for Britton\'s pr...
# 5   Given the power relations in Congress, this is...
# 6   They contrast the ineffectual "pork-laden" leg...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  The major bills are now being pushed by John K...
# 12  The major bills are now being pushed by John K...
# 13  The problem of relying upon these actors to sa...
# 14  The problem of relying upon these actors to sa...
# 15  If Zuma aims, therefore, to persuade the world...
# 16  The cuts promised by Sonjica just before Copen...
# 17  In reality, cuts promised in the Long-Term Mit...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5   Transition politics & climate finance  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                                 Actor    Type
# 0                  the Family and Marriage Society SA     ORG
# 1   the Southern African Faith Communities Environ...     ORG
# 2   the Southern African Faith Communities Environ...     ORG
# 3                                         Sue Britton  PERSON
# 4                                            Britton\     ORG
# 5                                            Congress     ORG
# 6              the Environmental Protection Agency\'s     ORG
# 7                               Chevron San Francisco     ORG
# 8                                                 EPA     ORG
# 9                                              Senate     ORG
# 10                                         John Kerry  PERSON
# 11                                   Joseph Lieberman  PERSON
# 12                                     Lindsay Graham  PERSON
# 13                                                ANC     ORG
# 14                                              House     ORG
# 15                                               Zuma  PERSON
# 16                                         Copenhagen     ORG
# 17                  the Long-Term Mitigation Scenario     ORG
# 18                                              Sasol  PERSON
# 19                                              Eskom     ORG

# %%
# This is displaying a new row for each identified entity (so if >1 entity in same sentence, same sentence over >1 rows ) + One column per entity categorie (PERSON or ORG)



# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy3_top_topic.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]
        if entity_type == 'PERSON':
            expanded_data.append([sentence, topic, year, month, entity_name, None])
        elif entity_type == 'ORG':
            expanded_data.append([sentence, topic, year, month, None, entity_name])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'PERSON', 'ORG'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_3.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Many organisations, including the Southern Afr...
# 2   Many organisations, including the Southern Afr...
# 3   "We\'re confident this will prove more cost-ef...
# 4   There was widespread support for Britton\'s pr...
# 5   Given the power relations in Congress, this is...
# 6   They contrast the ineffectual "pork-laden" leg...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  The major bills are now being pushed by John K...
# 12  The major bills are now being pushed by John K...
# 13  The problem of relying upon these actors to sa...
# 14  The problem of relying upon these actors to sa...
# 15  If Zuma aims, therefore, to persuade the world...
# 16  The cuts promised by Sonjica just before Copen...
# 17  In reality, cuts promised in the Long-Term Mit...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month            PERSON  \
# 0                            Eskom crisis  2010      1              None
# 1                            Eskom crisis  2010      1              None
# 2                            Eskom crisis  2010      1              None
# 3                            Eskom crisis  2010      1       Sue Britton
# 4                            Eskom crisis  2010      1              None
# 5   Transition politics & climate finance  2010      1              None
# 6   Transition politics & climate finance  2010      1              None
# 7   Transition politics & climate finance  2010      1              None
# 8   Transition politics & climate finance  2010      1              None
# 9   Transition politics & climate finance  2010      1              None
# 10  Transition politics & climate finance  2010      1        John Kerry
# 11  Transition politics & climate finance  2010      1  Joseph Lieberman
# 12  Transition politics & climate finance  2010      1    Lindsay Graham
# 13  Transition politics & climate finance  2010      1              None
# 14  Transition politics & climate finance  2010      1              None
# 15  Transition politics & climate finance  2010      1              Zuma
# 16  Transition politics & climate finance  2010      1              None
# 17  Transition politics & climate finance  2010      1              None
# 18  Transition politics & climate finance  2010      1             Sasol
# 19  Transition politics & climate finance  2010      1              None
#
#                                                   ORG
# 0                  the Family and Marriage Society SA
# 1   the Southern African Faith Communities Environ...
# 2   the Southern African Faith Communities Environ...
# 3                                                None
# 4                                            Britton\
# 5                                            Congress
# 6              the Environmental Protection Agency\'s
# 7                               Chevron San Francisco
# 8                                                 EPA
# 9                                              Senate
# 10                                               None
# 11                                               None
# 12                                               None
# 13                                                ANC
# 14                                              House
# 15                                               None
# 16                                         Copenhagen
# 17                  the Long-Term Mitigation Scenario
# 18                                               None
# 19                                              Eskom

# %% [markdown]
# # NER including Location

# %% [markdown]
# # Neuer Abschnitt

# %%
import pandas as pd
import nltk
from tqdm import tqdm
import spacy
from collections import Counter
import ast

nltk.download('punkt')

# Read the CSV file
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/coal_data_filtered_nodup_cleaned3.csv'
df = pd.read_csv(path_to_csv)

# Load the file with the info on top topic per document
path_to_df_top = '/content/drive/MyDrive/Colab Notebooks/topic_model_3_k20_srl_2.csv'
df_top = pd.read_csv(path_to_df_top)

# Merge the datasets based on id column
df = df.merge(df_top, left_on='Unnamed: 0.1', right_on='Unnamed: 0.1', how='left')

# Extract Year and Month from the Date column
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

print("Merged DataFrame:")
print(df.head())

# List unique topics in the DataFrame
unique_topics = df['Dominant Topic'].unique()
print("Unique topics in the DataFrame:", unique_topics)

# Filter out the topics of no interest
topics_of_no_interest = ["Mining market dynamics", "Stopwords/False Positives 1", "Stopwords/False Positives 2", "Indian South Africans history", "Coal transport"]
df = df[~df['Dominant Topic'].isin(topics_of_no_interest)] # is not it

print(f"Filtered DataFrame has {len(df)} rows after filtering by topics.")

# Extract necessary columns
df_subset = df[['Article_Text', 'Dominant Topic', 'Year', 'Month']]

print(f"Subset DataFrame has {len(df_subset)} rows.")

# Initialize an empty list to store sentences and topics
data = []

# Function to truncate sentences
def truncate_sentence(sentence, max_length=50):
    words = sentence.split()
    if len(words) > max_length:
        sentence = ' '.join(words[:max_length])
    return sentence

# Iterate over the text of the articles
for index, row in df_subset.iterrows():
    text = row['Article_Text']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    # Split the text into sentences using NLTK's sent_tokenize function
    text_sentences = nltk.sent_tokenize(text)
    # Check each sentence for the presence of the word "coal"
    for i, sentence in enumerate(text_sentences):
        # Convert the sentence to lowercase for case-insensitive matching
        sentence_lower = sentence.lower()
        # Check if the sentence contains the word "coal"
        if "coal" in sentence_lower:
            # Collect the sentence before, the sentence with "coal", and the sentence after
            before = text_sentences[i-1] if i > 0 else ""
            after = text_sentences[i+1] if i < len(text_sentences) - 1 else ""
            sentences_to_add = [before, sentence, after]
            for sent in sentences_to_add:
                if sent:  # Only add non-empty sentences
                    truncated_sentence = truncate_sentence(sent)
                    data.append((truncated_sentence, topic, year, month))

print(f"Collected {len(data)} sentences containing the word 'coal' and their surrounding context.")

# Load the pre-trained spaCy model for NER
nlp = spacy.load('en_core_web_sm')

# Function to predict entities using spaCy
def predict_ner_spacy(data):
    predictions = []
    for sentence, topic, year, month in tqdm(data, desc="Predicting NER with spaCy"):
        doc = nlp(sentence)
        entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['PERSON', 'ORG', 'LOC']]
        predictions.append((sentence, topic, year, month, entities))
    return predictions

# Run prediction
predictions = predict_ner_spacy(data)

# Create an empty list to store the data for the DataFrame
df_data = []

for sentence, topic, year, month, entities in predictions:
    df_data.append([sentence, topic, year, month, entities])

# Create a DataFrame from the data list
df_ner = pd.DataFrame(df_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entities'])

# Export the DataFrame as a CSV file
df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy4.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))

# Correcting misclassified entities by creating a mapping
misclassified_entities = {
    'Mpumalanga': 'LOC',
    # Add more known misclassifications here
}

# Initialize a list to store the expanded rows with correct entity types
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]

        # Correct misclassified entities
        if entity_name in misclassified_entities:
            entity_type = misclassified_entities[entity_name]

        if entity_type == 'PERSON':
            expanded_data.append([sentence, topic, year, month, entity_name, None, None])
        elif entity_type == 'ORG':
            expanded_data.append([sentence, topic, year, month, None, entity_name, None])
        elif entity_type == 'LOC':
            expanded_data.append([sentence, topic, year, month, None, None, entity_name])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'PERSON', 'ORG', 'LOC'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_2_1.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))

# Create a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in unique_topics if topic not in topics_of_no_interest}

for sentence, topic, year, month, entities in predictions:
    entities_by_topic[topic].extend(entities)

# Compute frequency of each entity per topic
summary_statistics = {}

for topic, entities in entities_by_topic.items():
    counter = Counter(entities)
    summary_statistics[topic] = counter.most_common()

# Create a DataFrame to display the summary statistics
summary_data = []

for topic, entity_list in summary_statistics.items():
    for (entity_text, entity_type), count in entity_list:
        summary_data.append([topic, entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Topic', 'Entity', 'Type', 'Count'])

# Export the DataFrame as a CSV file
df_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_spacy4_summary_statistics.csv', index=False)

# Display the DataFrame
print(df_summary.head(20))
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Merged DataFrame:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2         168
# 1             3         261
# 2             4         263
# 3             5         360
# 4             6         361
#
#                                         Jurisdiction  Location ContentType  \
# 0                                      International       NaN        News
# 1                                      International       NaN        News
# 2  U.S. Federal; International; Massachusetts; Wa...       NaN        News
# 3                                      International       NaN        News
# 4                                      International       NaN        News
#
#             Byline  WordLength  WebNewsUrl  Geography  NegativeNews  ...  \
# 0              NaN        1860         NaN        NaN           NaN  ...
# 1     Ingi Salgado         700         NaN        NaN           NaN  ...
# 2     Patrick Bond        1768         NaN        NaN           NaN  ...
# 3  Eleanor Momberg         867         NaN        NaN           NaN  ...
# 4  Donwald Pressly         440         NaN        NaN           NaN  ...
#
#    State                                            Country  \
# 0    NaN                                       SOUTH AFRICA
# 1    NaN                      SOUTH AFRICA; SOUTHERN AFRICA
# 2  EARTH  SOUTH AFRICA; INDIA; AFRICA; BRAZIL; CHINA; UN...
# 3    NaN                                       SOUTH AFRICA
# 4    NaN                                       SOUTH AFRICA
#
#                              News Outlet  \
# 0  The Sunday Independent (South Africa)
# 1  The Sunday Independent (South Africa)
# 2  The Sunday Independent (South Africa)
# 3  The Sunday Independent (South Africa)
# 4  The Sunday Independent (South Africa)
#
#                                  Word Count ArticleCount  frequency  version  \
# 0                   LIFE; Pg. 30, 1860words          368     weekly    print
# 1  BUSINESS REPORT WEEKEND; Pg. 1, 700words          368     weekly    print
# 2                           NEWS, 1768words          368     weekly    print
# 3                    NEWS; Pg. 10, 867words          368     weekly    print
# 4  BUSINESS REPORT WEEKEND; Pg. 1, 440words          368     weekly    print
#
#                           Dominant Topic  Year  Month
# 0            Stopwords/False Positives 2  2010      1
# 1                           Eskom crisis  2010      1
# 2  Transition politics & climate finance  2010      1
# 3                   Anti-mining activism  2010      1
# 4                     Electricity crisis  2010      1
#
# [5 rows x 54 columns]
# Unique topics in the DataFrame: ['Stopwords/False Positives 2' 'Eskom crisis'
#  'Transition politics & climate finance' 'Anti-mining activism'
#  'Electricity crisis' 'Daily political business' 'Coal transport'
#  'Climate change impact' 'Coal trade relations'
#  'Energy policies & renewables' 'Mining market dynamics'
#  'Safety & illegal activities' 'State intervention in mining'
#  'Indian South Africans history' 'State capture & corruption'
#  'Oil & gas alternatives' 'Coal labor issues' 'Mining investments'
#  'Air pollution' 'Stopwords/False Positives 1']
# Filtered DataFrame has 6160 rows after filtering by topics.
# Subset DataFrame has 6160 rows.
# Collected 49171 sentences containing the word 'coal' and their surrounding context.
# Predicting NER with spaCy: 100%|██████████| 49171/49171 [13:26<00:00, 60.95it/s]
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   "We\'re confident this will prove more cost-ef...
# 5   There was widespread support for Britton\'s pr...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  It is also based on "cap and trade" in which p...
# 12  The problem of relying upon these actors to sa...
# 13  The boiler deals give the ruling party a multi...
# 14  If Zuma aims, therefore, to persuade the world...
# 15  The cuts promised by Sonjica just before Copen...
# 16  In reality, cuts promised in the Long-Term Mit...
# 17  As the Eskom tariff hearings organised by the ...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                              Entities
# 0         [(the Family and Marriage Society SA, ORG)]
# 1                                                  []
# 2   [(the Southern African Faith Communities Envir...
# 3   [(the Southern African Faith Communities Envir...
# 4                             [(Sue Britton, PERSON)]
# 5                                   [(Britton\, ORG)]
# 6                                   [(Congress, ORG)]
# 7   [(the Environmental Protection Agency\'s, ORG)...
# 8                                        [(EPA, ORG)]
# 9                                     [(Senate, ORG)]
# 10  [(John Kerry, PERSON), (Joseph Lieberman, PERS...
# 11                                                 []
# 12                         [(ANC, ORG), (House, ORG)]
# 13                                                 []
# 14                                   [(Zuma, PERSON)]
# 15                                [(Copenhagen, ORG)]
# 16  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 17                       [(Eskom, ORG), (Eskom, ORG)]
# 18  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 19                       [(Eskom, ORG), (Eskom, ORG)]
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Many organisations, including the Southern Afr...
# 2   Many organisations, including the Southern Afr...
# 3   "We\'re confident this will prove more cost-ef...
# 4   There was widespread support for Britton\'s pr...
# 5   Given the power relations in Congress, this is...
# 6   They contrast the ineffectual "pork-laden" leg...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  The major bills are now being pushed by John K...
# 12  The major bills are now being pushed by John K...
# 13  The problem of relying upon these actors to sa...
# 14  The problem of relying upon these actors to sa...
# 15  If Zuma aims, therefore, to persuade the world...
# 16  The cuts promised by Sonjica just before Copen...
# 17  In reality, cuts promised in the Long-Term Mit...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month            PERSON  \
# 0                            Eskom crisis  2010      1              None
# 1                            Eskom crisis  2010      1              None
# 2                            Eskom crisis  2010      1              None
# 3                            Eskom crisis  2010      1       Sue Britton
# 4                            Eskom crisis  2010      1              None
# 5   Transition politics & climate finance  2010      1              None
# 6   Transition politics & climate finance  2010      1              None
# 7   Transition politics & climate finance  2010      1              None
# 8   Transition politics & climate finance  2010      1              None
# 9   Transition politics & climate finance  2010      1              None
# 10  Transition politics & climate finance  2010      1        John Kerry
# 11  Transition politics & climate finance  2010      1  Joseph Lieberman
# 12  Transition politics & climate finance  2010      1    Lindsay Graham
# 13  Transition politics & climate finance  2010      1              None
# 14  Transition politics & climate finance  2010      1              None
# 15  Transition politics & climate finance  2010      1              Zuma
# 16  Transition politics & climate finance  2010      1              None
# 17  Transition politics & climate finance  2010      1              None
# 18  Transition politics & climate finance  2010      1             Sasol
# 19  Transition politics & climate finance  2010      1              None
#
#                                                   ORG   LOC
# 0                  the Family and Marriage Society SA  None
# 1   the Southern African Faith Communities Environ...  None
# 2   the Southern African Faith Communities Environ...  None
# 3                                                None  None
# 4                                            Britton\  None
# 5                                            Congress  None
# 6              the Environmental Protection Agency\'s  None
# 7                               Chevron San Francisco  None
# 8                                                 EPA  None
# 9                                              Senate  None
# 10                                               None  None
# 11                                               None  None
# 12                                               None  None
# 13                                                ANC  None
# 14                                              House  None
# 15                                               None  None
# 16                                         Copenhagen  None
# 17                  the Long-Term Mitigation Scenario  None
# 18                                               None  None
# 19                                              Eskom  None
#            Topic                Entity    Type  Count
# 0   Eskom crisis                 Eskom     ORG    475
# 1   Eskom crisis                Eskom\     ORG     88
# 2   Eskom crisis                    SA     ORG     60
# 3   Eskom crisis                   ANC     ORG     41
# 4   Eskom crisis       South Africa\'s     LOC     38
# 5   Eskom crisis                 Nersa     ORG     34
# 6   Eskom crisis                Kusile     ORG     24
# 7   Eskom crisis              Treasury     ORG     19
# 8   Eskom crisis            Mpumalanga  PERSON     16
# 9   Eskom crisis             Transnet\     ORG     16
# 10  Eskom crisis        the World Bank     ORG     15
# 11  Eskom crisis                   it\     ORG     15
# 12  Eskom crisis             Ramaphosa  PERSON     14
# 13  Eskom crisis                Durban     ORG     13
# 14  Eskom crisis               Gordhan  PERSON     13
# 15  Eskom crisis              treasury     ORG     13
# 16  Eskom crisis                   SAA     ORG     11
# 17  Eskom crisis        Gwede Mantashe  PERSON     11
# 18  Eskom crisis              Transnet     ORG     11
# 19  Eskom crisis  the Chamber of Mines     ORG     10

# %%
# This is displaying Person and ORG as seperate columns

path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy4.csv'
df_ner = pd.read_csv(path_to_csv)


# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize columns for Persons and Organizations
df_ner['Persons'] = df_ner['Entities'].apply(lambda entities: [entity[0] for entity in entities if entity[1] == 'PERSON'])
df_ner['Organizations'] = df_ner['Entities'].apply(lambda entities: [entity[0] for entity in entities if entity[1] == 'ORG'])
df_ner['Locations'] = df_ner['Entities'].apply(lambda entities: [entity[0] for entity in entities if entity[1] == 'LOC'])

df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_2_1.csv', index=False)

# Display the DataFrame with the new columns
print(df_ner.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   "We\'re confident this will prove more cost-ef...
# 5   There was widespread support for Britton\'s pr...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  It is also based on "cap and trade" in which p...
# 12  The problem of relying upon these actors to sa...
# 13  The boiler deals give the ruling party a multi...
# 14  If Zuma aims, therefore, to persuade the world...
# 15  The cuts promised by Sonjica just before Copen...
# 16  In reality, cuts promised in the Long-Term Mit...
# 17  As the Eskom tariff hearings organised by the ...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                              Entities  \
# 0         [(the Family and Marriage Society SA, ORG)]
# 1                                                  []
# 2   [(the Southern African Faith Communities Envir...
# 3   [(the Southern African Faith Communities Envir...
# 4                             [(Sue Britton, PERSON)]
# 5                                   [(Britton\, ORG)]
# 6                                   [(Congress, ORG)]
# 7   [(the Environmental Protection Agency\'s, ORG)...
# 8                                        [(EPA, ORG)]
# 9                                     [(Senate, ORG)]
# 10  [(John Kerry, PERSON), (Joseph Lieberman, PERS...
# 11                                                 []
# 12                         [(ANC, ORG), (House, ORG)]
# 13                                                 []
# 14                                   [(Zuma, PERSON)]
# 15                                [(Copenhagen, ORG)]
# 16  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 17                       [(Eskom, ORG), (Eskom, ORG)]
# 18  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 19                       [(Eskom, ORG), (Eskom, ORG)]
#
#                                            Persons  \
# 0                                               []
# 1                                               []
# 2                                               []
# 3                                               []
# 4                                    [Sue Britton]
# 5                                               []
# 6                                               []
# 7                                               []
# 8                                               []
# 9                                               []
# 10  [John Kerry, Joseph Lieberman, Lindsay Graham]
# 11                                              []
# 12                                              []
# 13                                              []
# 14                                          [Zuma]
# 15                                              []
# 16                                         [Sasol]
# 17                                              []
# 18                                         [Sasol]
# 19                                              []
#
#                                         Organizations Locations
# 0                [the Family and Marriage Society SA]        []
# 1                                                  []        []
# 2   [the Southern African Faith Communities Enviro...        []
# 3   [the Southern African Faith Communities Enviro...        []
# 4                                                  []        []
# 5                                          [Britton\]        []
# 6                                          [Congress]        []
# 7   [the Environmental Protection Agency\'s, Chevr...        []
# 8                                               [EPA]        []
# 9                                            [Senate]        []
# 10                                                 []        []
# 11                                                 []        []
# 12                                       [ANC, House]        []
# 13                                                 []        []
# 14                                                 []        []
# 15                                       [Copenhagen]        []
# 16                [the Long-Term Mitigation Scenario]        []
# 17                                     [Eskom, Eskom]        []
# 18                [the Long-Term Mitigation Scenario]        []
# 19                                     [Eskom, Eskom]        []

# %%
# This is displaying a new row for each identified entity (so if >1 entity in same sentence, same sentence over >1 rows )

# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy4.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]
        expanded_data.append([sentence, topic, year, month, entity_name, entity_type])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entity', 'Type'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_2_2.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Many organisations, including the Southern Afr...
# 2   Many organisations, including the Southern Afr...
# 3   "We\'re confident this will prove more cost-ef...
# 4   There was widespread support for Britton\'s pr...
# 5   Given the power relations in Congress, this is...
# 6   They contrast the ineffectual "pork-laden" leg...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  The major bills are now being pushed by John K...
# 12  The major bills are now being pushed by John K...
# 13  The problem of relying upon these actors to sa...
# 14  The problem of relying upon these actors to sa...
# 15  If Zuma aims, therefore, to persuade the world...
# 16  The cuts promised by Sonjica just before Copen...
# 17  In reality, cuts promised in the Long-Term Mit...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5   Transition politics & climate finance  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                                Entity    Type
# 0                  the Family and Marriage Society SA     ORG
# 1   the Southern African Faith Communities Environ...     ORG
# 2   the Southern African Faith Communities Environ...     ORG
# 3                                         Sue Britton  PERSON
# 4                                            Britton\     ORG
# 5                                            Congress     ORG
# 6              the Environmental Protection Agency\'s     ORG
# 7                               Chevron San Francisco     ORG
# 8                                                 EPA     ORG
# 9                                              Senate     ORG
# 10                                         John Kerry  PERSON
# 11                                   Joseph Lieberman  PERSON
# 12                                     Lindsay Graham  PERSON
# 13                                                ANC     ORG
# 14                                              House     ORG
# 15                                               Zuma  PERSON
# 16                                         Copenhagen     ORG
# 17                  the Long-Term Mitigation Scenario     ORG
# 18                                              Sasol  PERSON
# 19                                              Eskom     ORG

# %%
# This is displaying a new row for each identified entity (so if >1 entity in same sentence, same sentence over >1 rows ) + One column per entity categorie (PERSON or ORG)



# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy4.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]
        if entity_type == 'PERSON':
            expanded_data.append([sentence, topic, year, month, entity_name, None, None])
        elif entity_type == 'ORG':
            expanded_data.append([sentence, topic, year, month, None, entity_name, None])
        elif entity_type == 'LOC':
            expanded_data.append([sentence, topic, year, month, None, None, entity_name])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'PERSON', 'ORG', 'LOC'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_2_3.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Many organisations, including the Southern Afr...
# 2   Many organisations, including the Southern Afr...
# 3   "We\'re confident this will prove more cost-ef...
# 4   There was widespread support for Britton\'s pr...
# 5   Given the power relations in Congress, this is...
# 6   They contrast the ineffectual "pork-laden" leg...
# 7   They contrast the ineffectual "pork-laden" leg...
# 8   In December, the EPA issued an "endangerment" ...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  The major bills are now being pushed by John K...
# 12  The major bills are now being pushed by John K...
# 13  The problem of relying upon these actors to sa...
# 14  The problem of relying upon these actors to sa...
# 15  If Zuma aims, therefore, to persuade the world...
# 16  The cuts promised by Sonjica just before Copen...
# 17  In reality, cuts promised in the Long-Term Mit...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month            PERSON  \
# 0                            Eskom crisis  2010      1              None
# 1                            Eskom crisis  2010      1              None
# 2                            Eskom crisis  2010      1              None
# 3                            Eskom crisis  2010      1       Sue Britton
# 4                            Eskom crisis  2010      1              None
# 5   Transition politics & climate finance  2010      1              None
# 6   Transition politics & climate finance  2010      1              None
# 7   Transition politics & climate finance  2010      1              None
# 8   Transition politics & climate finance  2010      1              None
# 9   Transition politics & climate finance  2010      1              None
# 10  Transition politics & climate finance  2010      1        John Kerry
# 11  Transition politics & climate finance  2010      1  Joseph Lieberman
# 12  Transition politics & climate finance  2010      1    Lindsay Graham
# 13  Transition politics & climate finance  2010      1              None
# 14  Transition politics & climate finance  2010      1              None
# 15  Transition politics & climate finance  2010      1              Zuma
# 16  Transition politics & climate finance  2010      1              None
# 17  Transition politics & climate finance  2010      1              None
# 18  Transition politics & climate finance  2010      1             Sasol
# 19  Transition politics & climate finance  2010      1              None
#
#                                                   ORG   LOC
# 0                  the Family and Marriage Society SA  None
# 1   the Southern African Faith Communities Environ...  None
# 2   the Southern African Faith Communities Environ...  None
# 3                                                None  None
# 4                                            Britton\  None
# 5                                            Congress  None
# 6              the Environmental Protection Agency\'s  None
# 7                               Chevron San Francisco  None
# 8                                                 EPA  None
# 9                                              Senate  None
# 10                                               None  None
# 11                                               None  None
# 12                                               None  None
# 13                                                ANC  None
# 14                                              House  None
# 15                                               None  None
# 16                                         Copenhagen  None
# 17                  the Long-Term Mitigation Scenario  None
# 18                                               None  None
# 19                                              Eskom  None

# %% [markdown]
# # NER including location + a bit cleaned and only top 40 entities per topic

# %%
from collections import Counter

# Load the CSV file with NER predictions
#path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy4.csv'
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv'

df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store all entities
all_entities = []

# Iterate over the DataFrame rows to collect all entities
for index, row in df_ner.iterrows():
    entities = row['Entities']
    # Normalize entities by removing backslashes and handling "The"/"the"
    normalized_entities = [(ent[0].replace('\\', '').replace('The ', '').replace('the ', '').replace("'s", ''), ent[1]) for ent in entities]
    all_entities.extend(normalized_entities)

# Count the frequency of each entity
entity_counter = Counter(all_entities)

# Get the top 40 entities
#top_40_entities = entity_counter.most_common(40)

# Create a summary DataFrame for the top 40 entities
#summary_data = []

#for (entity_text, entity_type), count in top_40_entities:
#    summary_data.append([entity_text, entity_type, count])

#df_summary = pd.DataFrame(summary_data, columns=['Entity', 'Type', 'Count'])

# Export the summary DataFrame as a CSV file
#df_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/top_40_entities_summary.csv', index=False)

# Display the summary DataFrame
#print(df_summary.head(60))



# Get the top 400 entities
top_400_entities = entity_counter.most_common(400)

# Create a summary DataFrame for the top 400 entities
summary_data = []

for (entity_text, entity_type), count in top_400_entities:
    summary_data.append([entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Entity', 'Type', 'Count'])

# Export the summary DataFrame as a CSV file
df_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/top_400_entities_summary.csv', index=False)

# Display the summary DataFrame
print(df_summary.head(60))
# Out:
#                              Entity    Type  Count
# 0                             Eskom     ORG   5249
# 1                                SA     ORG   2336
# 2                        Mpumalanga     LOC   1415
# 3                          Glencore     ORG    933
# 4                            Exxaro     ORG    839
# 5                              CoAL     ORG    828
# 6                      Optimum Coal     ORG    706
# 7                            Kusile     LOC    704
# 8                             Sasol     ORG    689
# 9                           Optimum     ORG    689
# 10                              ANC     ORG    674
# 11                   Coal of Africa     ORG    596
# 12                           Africa     LOC    539
# 13                            Gupta  PERSON    514
# 14                             Vele     LOC    371
# 15                        Ramaphosa  PERSON    334
# 16                              JSE     ORG    295
# 17                       World Bank     ORG    257
# 18       Richards Bay Coal Terminal     LOC    255
# 19                         Mantashe  PERSON    251
# 20                    KwaZulu-Natal     LOC    250
# 21                              NUM     ORG    246
# 22                             Coal  PERSON    234
# 23                           Durban     LOC    232
# 24                           Guptas     ORG    228
# 25                             Coal     ORG    225
# 26                           Europe     LOC    221
# 27                     BHP Billiton     ORG    220
# 28                              IRP     ORG    219
# 29                           Tegeta     ORG    210
# 30                  Cyril Ramaphosa  PERSON    188
# 31                           Majuba     LOC    168
# 32                              BEE     ORG    150
# 33                         Treasury     ORG    150
# 34                           Tegeta  PERSON    150
# 35                           Komati     LOC    140
# 36                     Richards Bay     LOC    135
# 37                       Jacob Zuma  PERSON    134
# 38                   Gwede Mantashe  PERSON    128
# 39                             Zuma  PERSON    127
# 40                     Eastern Cape     LOC    124
# 41                          Witbank     ORG    124
# 42                         Transnet     ORG    117
# 43                       Greenpeace     ORG    115
# 44                              BHP     ORG    112
# 45                       groundWork     ORG    109
# 46                          Makhado  PERSON    109
# 47                      Ibutho Coal     ORG    107
# 48  Department of Mineral Resources     ORG    101
# 49                            Nersa     ORG    101
# 50                 Chamber of Mines     ORG     99
# 51                       Mozambique     ORG     98
# 52    National Union of Mineworkers     ORG     96
# 53                     Brian Molefe  PERSON     95
# 54                            House     ORG     91
# 55                          Wescoal     ORG     91
# 56                  John Wallington  PERSON     89
# 57                         Thungela  PERSON     89
# 58                             Asia     LOC     89
# 59                 Exxaro Resources     ORG     88

# %% [markdown]
# # Now try to give some custom help to the model

# %%
# Read the CSV file
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/coal_data_filtered_nodup_cleaned3.csv'
df = pd.read_csv(path_to_csv)

# Load the file with the info on top topic per document
path_to_df_top = '/content/drive/MyDrive/Colab Notebooks/topic_model_3_k20_srl_2.csv'
df_top = pd.read_csv(path_to_df_top)

# Merge the datasets based on id column
df = df.merge(df_top, left_on='Unnamed: 0.1', right_on='Unnamed: 0.1', how='left')

# Function to clean text
def clean_text(text):
    # Replace \' with '
    text = text.replace("\'", "")
    # Replace \" with "
    text = text.replace('\"', "")
    text = text.replace('\"', '')
    text = text.replace('\s', '')
    text = text.replace('\t', '')
    text = text.replace('\n', '')
    text = text.replace('\r', '')


    return text

# Clean Article_Text column
df['Article_Text'] = df['Article_Text'].apply(clean_text)


# Extract Year and Month from the Date column
df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

print("Merged DataFrame:")
print(df.head())

# List unique topics in the DataFrame
unique_topics = df['Dominant Topic'].unique()
print("Unique topics in the DataFrame:", unique_topics)

# Filter out the topics of no interest
topics_of_no_interest = ["Mining market dynamics", "Stopwords/False Positives 1", "Stopwords/False Positives 2", "Indian South Africans history", "Coal transport"]
df = df[~df['Dominant Topic'].isin(topics_of_no_interest)]

print(f"Filtered DataFrame has {len(df)} rows after filtering by topics.")

# Extract necessary columns
df_subset = df[['Article_Text', 'Dominant Topic', 'Year', 'Month']]

print(f"Subset DataFrame has {len(df_subset)} rows.")


# Initialize an empty list to store sentences and topics
data = []

# Function to truncate sentences
def truncate_sentence(sentence, max_length=50):
    words = sentence.split()
    if len(words) > max_length:
        sentence = ' '.join(words[:max_length])
    return sentence

for index, row in df_subset.iterrows():
    text = row['Article_Text']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    # Clean text before processing
    cleaned_text = clean_text(text)
    # Split the text into sentences using NLTK's sent_tokenize function
    text_sentences = nltk.sent_tokenize(cleaned_text)
    # Check each sentence for the presence of the word "coal"
    for i, sentence in enumerate(text_sentences):
        # Convert the sentence to lowercase for case-insensitive matching
        sentence_lower = sentence.lower()
        # Check if the sentence contains the word "coal"
        if "coal" in sentence_lower:
            # Collect the sentence before, the sentence with "coal", and the sentence after
            before = text_sentences[i-1] if i > 0 else ""
            after = text_sentences[i+1] if i < len(text_sentences) - 1 else ""
            sentences_to_add = [before, sentence, after]
            for sent in sentences_to_add:
                if sent:  # Only add non-empty sentences
                    truncated_sentence = truncate_sentence(sent)
                    data.append((truncated_sentence, topic, year, month))


print(f"Collected {len(data)} sentences containing the word 'coal' and their surrounding context.")

# Load the pre-trained spaCy model for NER
nlp = spacy.load('en_core_web_sm')

# Create a custom entity ruler to handle specific cases
ruler = nlp.add_pipe("entity_ruler", before="ner")
patterns = [
    {"label": "ORG", "pattern": "Coal of Africa"},
    {"label": "LOC", "pattern": "Mpumalanga"},
    {"label": "ORG", "pattern": "Just Coal"},
    {"label": "ORG", "pattern": "Cosatu"},
    {"label": "ORG", "pattern": "Just Share"},
    {"label": "ORG", "pattern": "Greenpeace Africa"},
    {"label": "ORG", "pattern": "Greenpeace"},
    {"label": "LOC", "pattern": "Durban"},
    {"label": "ORG", "pattern": "groundWork"},
    {"label": "ORG", "pattern": "GroundWork"},
    {"label": "ORG", "pattern": "Groundwork"},
    {"label": "ORG", "pattern": "groundwork"},
    {"label": "ORG", "pattern": "Earthlife Africa"},
    {"label": "ORG", "pattern": "Glencore"},
    {"label": "ORG", "pattern": "Optimum Coal"},
    {"label": "ORG", "pattern": "Optimum"},
    {"label": "LOC", "pattern": "Richards Bay Coal Terminal"},
    {"label": "ORG", "pattern": "Sasol"},
    {"label": "LOC", "pattern": "Komati Power Station"},
    {"label": "ORG", "pattern": "Exxaro Resources"},
    {"label": "ORG", "pattern": "Exxaro"},
    {"label": "ORG", "pattern": "Climate Justice Coalition"},
    {"label": "LOC", "pattern": "Kusile"},
    {"label": "LOC", "pattern": "Komati"},
    {"label": "LOC", "pattern": "KwaZulu-Natal"},
    {"label": "LOC", "pattern": "Vele"},
    {"label": "LOC", "pattern": "Vele coal mine"},
    {"label": "LOC", "pattern": "Vele mine"},
    {"label": "ORG", "pattern": "Ibutho Coal"},
    {"label": "LOC", "pattern": "Majuba Power Station"},
    {"label": "LOC", "pattern": "Majuba"},
    {"label": "LOC", "pattern": "Vunene"},
   # {"label": "ORG", "pattern": "Germany"},
   # {"label": "ORG", "pattern": "France"},
   # {"label": "UK", "pattern": "UK"},
   # {"label": "LOC", "pattern": "US"},


  ]
ruler.add_patterns(patterns)

# Function to predict entities using spaCy with custom entity ruler
def predict_ner_spacy(data):
    predictions = []
    for sentence, topic, year, month in tqdm(data, desc="Predicting NER with spaCy"):
        doc = nlp(sentence)
        entities = [(ent.text, ent.label_) for ent in doc.ents if ent.label_ in ['PERSON', 'ORG', 'LOC']]
        predictions.append((sentence, topic, year, month, entities))
    return predictions

# Run prediction
predictions = predict_ner_spacy(data)

# Create an empty list to store the data for the DataFrame
df_data = []

for sentence, topic, year, month, entities in predictions:
    df_data.append([sentence, topic, year, month, entities])

# Create a DataFrame from the data list
df_ner = pd.DataFrame(df_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entities'])

# Export the DataFrame as a CSV file
df_ner.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv', index=False)

# Display the DataFrame
print(df_ner.head(20))



# Initialize a list to store the expanded rows with correct entity types
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]

        if entity_type == 'PERSON':
            expanded_data.append([sentence, topic, year, month, entity_name, None, None])
        elif entity_type == 'ORG':
            expanded_data.append([sentence, topic, year, month, None, entity_name, None])
        elif entity_type == 'LOC':
            expanded_data.append([sentence, topic, year, month, None, None, entity_name])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'PERSON', 'ORG', 'LOC'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_3_1.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))

# Create a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in unique_topics if topic not in topics_of_no_interest}

for sentence, topic, year, month, entities in predictions:
    entities_by_topic[topic].extend(entities)

# Compute frequency of each entity per topic
summary_statistics = {}

for topic, entities in entities_by_topic.items():
    counter = Counter(entities)
    summary_statistics[topic] = counter.most_common()

# Create a DataFrame to display the summary statistics
summary_data = []

for topic, entity_list in summary_statistics.items():
    for (entity_text, entity_type), count in entity_list:
        summary_data.append([topic, entity_text, entity_type, count])

df_summary = pd.DataFrame(summary_data, columns=['Topic', 'Entity', 'Type', 'Count'])

# Export the DataFrame as a CSV file
df_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_spacy5_summary_statistics.csv', index=False)

# Display the DataFrame
print(df_summary.head(20))
# Out:
# Merged DataFrame:
#    Unnamed: 0.1  Unnamed: 0  \
# 0             2         168
# 1             3         261
# 2             4         263
# 3             5         360
# 4             6         361
#
#                                         Jurisdiction  Location ContentType  \
# 0                                      International       NaN        News
# 1                                      International       NaN        News
# 2  U.S. Federal; International; Massachusetts; Wa...       NaN        News
# 3                                      International       NaN        News
# 4                                      International       NaN        News
#
#             Byline  WordLength  WebNewsUrl  Geography  NegativeNews  ...  \
# 0              NaN        1860         NaN        NaN           NaN  ...
# 1     Ingi Salgado         700         NaN        NaN           NaN  ...
# 2     Patrick Bond        1768         NaN        NaN           NaN  ...
# 3  Eleanor Momberg         867         NaN        NaN           NaN  ...
# 4  Donwald Pressly         440         NaN        NaN           NaN  ...
#
#    State                                            Country  \
# 0    NaN                                       SOUTH AFRICA
# 1    NaN                      SOUTH AFRICA; SOUTHERN AFRICA
# 2  EARTH  SOUTH AFRICA; INDIA; AFRICA; BRAZIL; CHINA; UN...
# 3    NaN                                       SOUTH AFRICA
# 4    NaN                                       SOUTH AFRICA
#
#                              News Outlet  \
# 0  The Sunday Independent (South Africa)
# 1  The Sunday Independent (South Africa)
# 2  The Sunday Independent (South Africa)
# 3  The Sunday Independent (South Africa)
# 4  The Sunday Independent (South Africa)
#
#                                  Word Count ArticleCount  frequency  version  \
# 0                   LIFE; Pg. 30, 1860words          368     weekly    print
# 1  BUSINESS REPORT WEEKEND; Pg. 1, 700words          368     weekly    print
# 2                           NEWS, 1768words          368     weekly    print
# 3                    NEWS; Pg. 10, 867words          368     weekly    print
# 4  BUSINESS REPORT WEEKEND; Pg. 1, 440words          368     weekly    print
#
#                           Dominant Topic  Year  Month
# 0            Stopwords/False Positives 2  2010      1
# 1                           Eskom crisis  2010      1
# 2  Transition politics & climate finance  2010      1
# 3                   Anti-mining activism  2010      1
# 4                     Electricity crisis  2010      1
#
# [5 rows x 54 columns]
# Unique topics in the DataFrame: ['Stopwords/False Positives 2' 'Eskom crisis'
#  'Transition politics & climate finance' 'Anti-mining activism'
#  'Electricity crisis' 'Daily political business' 'Coal transport'
#  'Climate change impact' 'Coal trade relations'
#  'Energy policies & renewables' 'Mining market dynamics'
#  'Safety & illegal activities' 'State intervention in mining'
#  'Indian South Africans history' 'State capture & corruption'
#  'Oil & gas alternatives' 'Coal labor issues' 'Mining investments'
#  'Air pollution' 'Stopwords/False Positives 1']
# Filtered DataFrame has 6160 rows after filtering by topics.
# Subset DataFrame has 6160 rows.
# Collected 48767 sentences containing the word 'coal' and their surrounding context.
# Predicting NER with spaCy: 100%|██████████| 48767/48767 [12:34<00:00, 64.65it/s]
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   We\re confident this will prove more cost-effe...
# 5   There was widespread support for Britton propo...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual pork-laden legis...
# 8   In December, the EPA issued an endangerment fi...
# 9   Hence halting the legislation in the Senate is...
# 10  The major bills are now being pushed by John K...
# 11  It is also based on cap and trade in which pol...
# 12  The problem of relying upon these actors to sa...
# 13  The boiler deals give the ruling party a multi...
# 14  If Zuma aims, therefore, to persuade the world...
# 15  The cuts promised by Sonjica just before Copen...
# 16  In reality, cuts promised in the Long-Term Mit...
# 17  As the Eskom tariff hearings organised by the ...
# 18  In reality, cuts promised in the Long-Term Mit...
# 19  As the Eskom tariff hearings organised by the ...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                              Entities
# 0         [(the Family and Marriage Society SA, ORG)]
# 1                                      [(Eskom, ORG)]
# 2   [(the Southern African Faith Communities Envir...
# 3   [(the Southern African Faith Communities Envir...
# 4                             [(Sue Britton, PERSON)]
# 5                                    [(Britton, ORG)]
# 6                                   [(Congress, ORG)]
# 7   [(the Environmental Protection Agency, ORG), (...
# 8                     [(EPA, ORG), (GroundWork, ORG)]
# 9                                     [(Senate, ORG)]
# 10  [(John Kerry, PERSON), (Joseph Lieberman, PERS...
# 11                                                 []
# 12           [(Eskom, ORG), (ANC, ORG), (House, ORG)]
# 13                                                 []
# 14                                   [(Zuma, PERSON)]
# 15       [(Copenhagen, ORG), (Earthlife Africa, ORG)]
# 16  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 17                       [(Eskom, ORG), (Eskom, ORG)]
# 18  [(the Long-Term Mitigation Scenario, ORG), (Sa...
# 19                       [(Eskom, ORG), (Eskom, ORG)]
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   We\re confident this will prove more cost-effe...
# 5   There was widespread support for Britton propo...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual pork-laden legis...
# 8   They contrast the ineffectual pork-laden legis...
# 9   They contrast the ineffectual pork-laden legis...
# 10  In December, the EPA issued an endangerment fi...
# 11  In December, the EPA issued an endangerment fi...
# 12  Hence halting the legislation in the Senate is...
# 13  The major bills are now being pushed by John K...
# 14  The major bills are now being pushed by John K...
# 15  The major bills are now being pushed by John K...
# 16  The problem of relying upon these actors to sa...
# 17  The problem of relying upon these actors to sa...
# 18  The problem of relying upon these actors to sa...
# 19  If Zuma aims, therefore, to persuade the world...
#
#                            Dominant Topic  Year  Month            PERSON  \
# 0                            Eskom crisis  2010      1              None
# 1                            Eskom crisis  2010      1              None
# 2                            Eskom crisis  2010      1              None
# 3                            Eskom crisis  2010      1              None
# 4                            Eskom crisis  2010      1       Sue Britton
# 5                            Eskom crisis  2010      1              None
# 6   Transition politics & climate finance  2010      1              None
# 7   Transition politics & climate finance  2010      1              None
# 8   Transition politics & climate finance  2010      1              None
# 9   Transition politics & climate finance  2010      1              None
# 10  Transition politics & climate finance  2010      1              None
# 11  Transition politics & climate finance  2010      1              None
# 12  Transition politics & climate finance  2010      1              None
# 13  Transition politics & climate finance  2010      1        John Kerry
# 14  Transition politics & climate finance  2010      1  Joseph Lieberman
# 15  Transition politics & climate finance  2010      1    Lindsay Graham
# 16  Transition politics & climate finance  2010      1              None
# 17  Transition politics & climate finance  2010      1              None
# 18  Transition politics & climate finance  2010      1              None
# 19  Transition politics & climate finance  2010      1              Zuma
#
#                                                   ORG   LOC
# 0                  the Family and Marriage Society SA  None
# 1                                               Eskom  None
# 2   the Southern African Faith Communities Environ...  None
# 3   the Southern African Faith Communities Environ...  None
# 4                                                None  None
# 5                                             Britton  None
# 6                                            Congress  None
# 7                 the Environmental Protection Agency  None
# 8                                                 EPA  None
# 9                               Chevron San Francisco  None
# 10                                                EPA  None
# 11                                         GroundWork  None
# 12                                             Senate  None
# 13                                               None  None
# 14                                               None  None
# 15                                               None  None
# 16                                              Eskom  None
# 17                                                ANC  None
# 18                                              House  None
# 19                                               None  None
#            Topic           Entity    Type  Count
# 0   Eskom crisis            Eskom     ORG    609
# 1   Eskom crisis               SA     ORG     96
# 2   Eskom crisis           Kusile     LOC     95
# 3   Eskom crisis              ANC     ORG     56
# 4   Eskom crisis            Nersa     ORG     48
# 5   Eskom crisis       Mpumalanga     LOC     46
# 6   Eskom crisis         Treasury     ORG     30
# 7   Eskom crisis            Sasol     ORG     27
# 8   Eskom crisis           Durban     LOC     22
# 9   Eskom crisis        Ramaphosa  PERSON     20
# 10  Eskom crisis   the World Bank     ORG     16
# 11  Eskom crisis           Exxaro     ORG     15
# 12  Eskom crisis              SAA     ORG     14
# 13  Eskom crisis         Glencore     ORG     14
# 14  Eskom crisis  Cyril Ramaphosa  PERSON     14
# 15  Eskom crisis           Cosatu     ORG     13
# 16  Eskom crisis          Mboweni  PERSON     13
# 17  Eskom crisis        De Ruyter     ORG     13
# 18  Eskom crisis         Transnet     ORG     13
# 19  Eskom crisis         treasury     ORG     13

# %%
# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a dictionary to store entities by topic
entities_by_topic = {topic: [] for topic in df_ner['Dominant Topic'].unique()}

# Iterate over the DataFrame rows to collect entities by topic
for index, row in df_ner.iterrows():
    entities = row['Entities']
    topic = row['Dominant Topic']
    # Normalize entities by removing backslashes and handling "The"/"the"
    normalized_entities = [(ent[0].replace('\\', '').replace('The ', '').replace('the ', '').replace("'s", ''), ent[1]) for ent in entities]
    entities_by_topic[topic].extend(normalized_entities)

# Initialize an empty list to store the summary DataFrames
summary_dfs = []

# Compute top entities for each topic
for topic, entities in entities_by_topic.items():
    # Count the frequency of each entity
    entity_counter = Counter(entities)
    # Get the top 10 entities
    top_entities = entity_counter.most_common(40)
    # Create summary DataFrame for the top entities
    df_summary = pd.DataFrame(top_entities, columns=['Entity', 'Count'])
    df_summary['Type'] = df_summary['Entity'].apply(lambda x: next((ent[1] for ent in entities if ent[0] == x), ''))
    df_summary['Topic'] = topic
    # Append the summary DataFrame to the list
    summary_dfs.append(df_summary)

# Concatenate all topic-specific summary DataFrames into a single DataFrame
df_combined_summary = pd.concat(summary_dfs, ignore_index=True)

# Export the combined summary DataFrame as a CSV file
df_combined_summary.to_csv('/content/drive/MyDrive/Colab Notebooks/top_entities_summary_by_topic5.csv', index=False)

# Display the combined summary DataFrame
print(df_combined_summary.head(40))
# Out:
#                                     Entity  Count Type         Topic
# 0                             (Eskom, ORG)    609       Eskom crisis
# 1                                (SA, ORG)     96       Eskom crisis
# 2                            (Kusile, LOC)     95       Eskom crisis
# 3                               (ANC, ORG)     56       Eskom crisis
# 4                             (Nersa, ORG)     48       Eskom crisis
# 5                        (Mpumalanga, LOC)     46       Eskom crisis
# 6                          (Treasury, ORG)     30       Eskom crisis
# 7                        (World Bank, ORG)     28       Eskom crisis
# 8                             (Sasol, ORG)     27       Eskom crisis
# 9                            (Durban, LOC)     22       Eskom crisis
# 10                     (Ramaphosa, PERSON)     20       Eskom crisis
# 11                           (Exxaro, ORG)     15       Eskom crisis
# 12                              (SAA, ORG)     14       Eskom crisis
# 13                         (Glencore, ORG)     14       Eskom crisis
# 14               (Cyril Ramaphosa, PERSON)     14       Eskom crisis
# 15                           (Cosatu, ORG)     13       Eskom crisis
# 16                       (Mboweni, PERSON)     13       Eskom crisis
# 17                        (De Ruyter, ORG)     13       Eskom crisis
# 18                         (Transnet, ORG)     13       Eskom crisis
# 19                         (treasury, ORG)     13       Eskom crisis
# 20       (Richards Bay Coal Terminal, LOC)     12       Eskom crisis
# 21                (National Treasury, ORG)     12       Eskom crisis
# 22                (Gwede Mantashe, PERSON)     12       Eskom crisis
# 23                       (Gordhan, PERSON)     12       Eskom crisis
# 24                              (G20, ORG)     12       Eskom crisis
# 25         (Integrated Resource Plan, ORG)     10       Eskom crisis
# 26                (Pravin Gordhan, PERSON)     10       Eskom crisis
# 27  (National Energy Regulator of SA, ORG)     10       Eskom crisis
# 28                 (Chamber of Mines, ORG)     10       Eskom crisis
# 29                         (Mr Dames, ORG)      9       Eskom crisis
# 30                             (Coal, ORG)      8       Eskom crisis
# 31                           (Komati, LOC)      8       Eskom crisis
# 32                       (Parliament, ORG)      8       Eskom crisis
# 33                               (MW, ORG)      7       Eskom crisis
# 34                 (Malusi Gigaba, PERSON)      7       Eskom crisis
# 35                          (Finance, ORG)      7       Eskom crisis
# 36                         (Numsa, PERSON)      6       Eskom crisis
# 37                    (KwaZulu-Natal, LOC)      6       Eskom crisis
# 38                           (Guptas, ORG)      6       Eskom crisis
# 39       (Special Investigating Unit, ORG)      6       Eskom crisis

# %%
# This is displaying a new row for each identified entity (so if >1 entity in same sentence, same sentence over >1 rows )

# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]
        expanded_data.append([sentence, topic, year, month, entity_name, entity_type])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entity', 'Type'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_3_2.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   We\re confident this will prove more cost-effe...
# 5   There was widespread support for Britton propo...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual pork-laden legis...
# 8   They contrast the ineffectual pork-laden legis...
# 9   They contrast the ineffectual pork-laden legis...
# 10  In December, the EPA issued an endangerment fi...
# 11  In December, the EPA issued an endangerment fi...
# 12  Hence halting the legislation in the Senate is...
# 13  The major bills are now being pushed by John K...
# 14  The major bills are now being pushed by John K...
# 15  The major bills are now being pushed by John K...
# 16  The problem of relying upon these actors to sa...
# 17  The problem of relying upon these actors to sa...
# 18  The problem of relying upon these actors to sa...
# 19  If Zuma aims, therefore, to persuade the world...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                                Entity    Type
# 0                  the Family and Marriage Society SA     ORG
# 1                                               Eskom     ORG
# 2   the Southern African Faith Communities Environ...     ORG
# 3   the Southern African Faith Communities Environ...     ORG
# 4                                         Sue Britton  PERSON
# 5                                             Britton     ORG
# 6                                            Congress     ORG
# 7                 the Environmental Protection Agency     ORG
# 8                                                 EPA     ORG
# 9                               Chevron San Francisco     ORG
# 10                                                EPA     ORG
# 11                                         GroundWork     ORG
# 12                                             Senate     ORG
# 13                                         John Kerry  PERSON
# 14                                   Joseph Lieberman  PERSON
# 15                                     Lindsay Graham  PERSON
# 16                                              Eskom     ORG
# 17                                                ANC     ORG
# 18                                              House     ORG
# 19                                               Zuma  PERSON

# %%
import pandas as pd
import ast

# Lists of entities
societal_entities = [
    'Greenpeace', 'Earthlife Africa', 'groundWork', 'Greenpeace Africa', 'CER', 'Save Mapungubwe Coalition',
    'Endangered Wildlife Trust', 'Ezemvelo', 'Ted Blom', 'Chris Yelland', 'Prof Zeelie', 'Engelbrecht',
    'Von Blottnitz', 'Nelson Mandela Metropolitan University', 'CSIR', 'Just Coal', 'Vukani Environmental Justice Movement',
    'Mike Holland', 'Rico Euripidou', 'Centre for Environmental Rights', 'WWF', 'NGO', 'Birdlife SA', 'University of Cape Town',
    'Bench Marks Foundation', 'Federation for a Sustainable Environment' 'Global Energy Monitor'
]

unions_entities = [
    'Cosatu', 'NUM', 'National Union of Mineworkers', 'Numsa', 'Amcu', 'Association of Mineworkers and Construction Union',
    'Solidarity', 'Joseph Mathunjwa', 'Jim', 'Lesiba Seshoka', 'Congress of South African Trade Unions',
    'THE National Union of Mineworkers', 'Allied Workers Union'
]

other_business_entities = [
    'SAA', 'Transnet', 'Standard Bank', 'Nedbank', 'Gupta', 'Guptas', 'Brian Molefe', 'Tata', 'IPP', 'Google',
    'Shell', 'Mafutha', 'Royal Dutch Shell', 'Sunbird Energy', 'JSE'
]

mining_business_entities = [
    'Sasol', 'Exxaro', 'Glencore', 'Coal of Africa', 'CoAL', 'Ibutho Coal', 'John Wallington', 'Atha-Africa', 'Optimum',
    'BHP Billiton', 'BEE', 'BHP', 'Tegeta', 'ExxonMobil', 'MMTC', 'Minerals Council SA', 'Umsobomvu Coal',
    'Elitheni', 'AEMFC', 'Teke', 'SAEC', 'Mike Teke', 'Mazizi Msutu', 'Tegeta Exploration and Resources', 'Wescoal',
    'Umthombo Resources', 'ICVL', 'Chamber of Mines', 'Shanduka Coal', 'Delmas Coal', 'Kangra Coal', 'Impala Platinum',
    'AngloGold Ashanti', 'Firestone', 'Xstrata', 'Continental Coal', 'Xstrata Coal'
]

international_actors = [
    'World Bank', 'G20', 'EU', 'UN', 'Intergovernmental Panel on Climate Change (IPCC', 'Xi Jinping', 'Xi',
    'International Energy Agency', 'World Health Organisation', 'the Conference of the Parties', 'United Nations', 'the European Union',
    'IPG', 'International Partners Group', 'Biden', ' Joe Biden', 'Brics'
]

political_entities = [
    'ANC', 'Nersa', 'Treasury', 'Ramaphosa', 'Cyril Ramaphosa', 'Mboweni', 'National Treasury', 'Gwede Mantashe',
    'Gordhan', 'Pravin Gordhan', 'National Energy Regulator of SA', 'Barbara Creecy', 'PCC', 'Presidential Climate Commission',
    'Department of Environmental Affairs', 'Department of Mineral Resources', 'Department of Water Affairs', 'DEA',
    'Edna Molewa', 'Malusi Gigaba', 'Zuma', 'EFF', 'Jacob Zuma', 'Malema', 'Parliament', 'Parks Tau', 'Kelvin',
    'Department of Trade and Industry', 'Department of Energy', 'Fikile Mbalula', 'Department of Mineral Resources and Energy',
    'DMRE', 'Susan Shabangu', 'Ms Shabangu', 'NPA', 'CCMA', 'Commission for Conciliation, Mediation and Arbitration (CCMA',
    'Democratic Alliance', 'DA', 'President Ramaphosa', "Jeff Radebe" # These 4 added by myself
]

eskom_entities = [
    'Eskom', 'De Ruyter', 'Andrew Etzinger', 'Brian Dames', 'Joffe', 'Hilary Joffe', 'Tshediso Matona', 'Brian Molefe',
    'Koko', 'Matshela Koko'
]

# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]

        # Determine the category of the entity
        if entity_name in societal_entities:
            category = 'Societal'
        elif entity_name in unions_entities:
            category = 'Unions'
        elif entity_name in other_business_entities:
            category = 'Other Business'
        elif entity_name in mining_business_entities:
            category = 'Mining Business'
        elif entity_name in international_actors:
            category = 'International'
        elif entity_name in political_entities:
            category = 'Political'
        elif entity_name in eskom_entities:
            category = 'Eskom'
        else:
            category = 'No Entity'

        expanded_data.append([sentence, topic, year, month, entity_name, entity_type, category])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entity', 'Type', 'Category'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_with_categories.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   We\re confident this will prove more cost-effe...
# 5   There was widespread support for Britton propo...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual pork-laden legis...
# 8   They contrast the ineffectual pork-laden legis...
# 9   They contrast the ineffectual pork-laden legis...
# 10  In December, the EPA issued an endangerment fi...
# 11  In December, the EPA issued an endangerment fi...
# 12  Hence halting the legislation in the Senate is...
# 13  The major bills are now being pushed by John K...
# 14  The major bills are now being pushed by John K...
# 15  The major bills are now being pushed by John K...
# 16  The problem of relying upon these actors to sa...
# 17  The problem of relying upon these actors to sa...
# 18  The problem of relying upon these actors to sa...
# 19  If Zuma aims, therefore, to persuade the world...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                                Entity    Type   Category
# 0                  the Family and Marriage Society SA     ORG  No Entity
# 1                                               Eskom     ORG      Eskom
# 2   the Southern African Faith Communities Environ...     ORG  No Entity
# 3   the Southern African Faith Communities Environ...     ORG  No Entity
# 4                                         Sue Britton  PERSON  No Entity
# 5                                             Britton     ORG  No Entity
# 6                                            Congress     ORG  No Entity
# 7                 the Environmental Protection Agency     ORG  No Entity
# 8                                                 EPA     ORG  No Entity
# 9                               Chevron San Francisco     ORG  No Entity
# 10                                                EPA     ORG  No Entity
# 11                                         GroundWork     ORG  No Entity
# 12                                             Senate     ORG  No Entity
# 13                                         John Kerry  PERSON  No Entity
# 14                                   Joseph Lieberman  PERSON  No Entity
# 15                                     Lindsay Graham  PERSON  No Entity
# 16                                              Eskom     ORG      Eskom
# 17                                                ANC     ORG  Political
# 18                                              House     ORG  No Entity
# 19                                               Zuma  PERSON  Political

# %%
# Summary: How many observations per category
category_counts = df_expanded['Category'].value_counts()
print(category_counts)

# Summary: How many observations per category per topic
category_topic_counts = df_expanded.groupby(['Category', 'Dominant Topic']).size().reset_index(name='Counts')
print(category_topic_counts)
# Export the summaries to CSV files
category_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_counts.csv', index=True)
category_topic_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_topic_counts.csv', index=False)
# Out:
# Category
# No Entity          39883
# Mining Business     6572
# Eskom               5573
# Political           2481
# Other Business      1580
# Societal             710
# Unions               533
# International        383
# Name: count, dtype: int64
#     Category                         Dominant Topic  Counts
# 0      Eskom                          Air pollution     108
# 1      Eskom                   Anti-mining activism      72
# 2      Eskom                  Climate change impact      58
# 3      Eskom                      Coal labor issues      55
# 4      Eskom                   Coal trade relations     102
# ..       ...                                    ...     ...
# 108   Unions                     Mining investments      10
# 109   Unions            Safety & illegal activities      11
# 110   Unions             State capture & corruption      29
# 111   Unions           State intervention in mining      17
# 112   Unions  Transition politics & climate finance      21
#
# [113 rows x 3 columns]

# %%
import pandas as pd
import ast

# Lists of entities
societal_entities = [
    'Greenpeace', 'Earthlife Africa', 'groundWork', 'Greenpeace Africa', 'CER', 'Save Mapungubwe Coalition',
    'Endangered Wildlife Trust', 'Ezemvelo', 'Ted Blom', 'Chris Yelland', 'Prof Zeelie', 'Engelbrecht',
    'Von Blottnitz', 'Nelson Mandela Metropolitan University', 'CSIR', 'Just Coal', 'Vukani Environmental Justice Movement',
    'Mike Holland', 'Rico Euripidou'
]

unions_entities = [
    'Cosatu', 'NUM', 'National Union of Mineworkers', 'Numsa', 'Amcu', 'Association of Mineworkers and Construction Union',
    'Solidarity', 'Joseph Mathunjwa', 'Jim', 'Lesiba Seshoka', 'Congress of South African Trade Unions',
    'THE National Union of Mineworkers', 'Allied Workers Union'
]

other_business_entities = [
    'SAA', 'Transnet', 'Standard Bank', 'Nedbank', 'Gupta', 'Guptas', 'Brian Molefe', 'Tata', 'IPP', 'Google',
    'Shell', 'Mafutha', 'Royal Dutch Shell', 'Sunbird Energy', 'JSE'
]

mining_business_entities = [
    'Sasol', 'Exxaro', 'Glencore', 'Coal of Africa', 'CoAL', 'Ibutho Coal', 'John Wallington', 'Atha-Africa', 'Optimum',
    'BHP Billiton', 'BEE', 'BHP', 'Tegeta', 'ExxonMobil', 'MMTC', 'Minerals Council SA', 'Umsobomvu Coal',
    'Elitheni', 'AEMFC', 'Teke', 'SAEC', 'Mike Teke', 'Mazizi Msutu', 'Tegeta Exploration and Resources', 'Wescoal',
    'Umthombo Resources', 'ICVL', 'Chamber of Mines', 'Shanduka Coal', 'Delmas Coal', 'Kangra Coal', 'Impala Platinum',
    'AngloGold Ashanti', 'Firestone', 'Xstrata', 'Continental Coal', 'Xstrata Coal'
]

international_actors = [
    'World Bank', 'G20', 'EU', 'UN', 'Intergovernmental Panel on Climate Change (IPCC', 'Xi Jinping',
    'International Energy Agency', 'World Health Organisation'
]

political_entities = [
    'ANC', 'Nersa', 'Treasury', 'Ramaphosa', 'Cyril Ramaphosa', 'Mboweni', 'National Treasury', 'Gwede Mantashe',
    'Gordhan', 'Pravin Gordhan', 'National Energy Regulator of SA', 'Barbara Creecy', 'PCC', 'Presidential Climate Commission',
    'Department of Environmental Affairs', 'Department of Mineral Resources', 'Department of Water Affairs', 'DEA',
    'Edna Molewa', 'Malusi Gigaba', 'Zuma', 'EFF', 'Jacob Zuma', 'Malema', 'Parliament', 'Parks Tau', 'Kelvin',
    'Department of Trade and Industry', 'Department of Energy', 'Fikile Mbalula', 'Department of Mineral Resources and Energy',
    'DMRE', 'Susan Shabangu', 'Ms Shabangu', 'NPA', 'CCMA', 'Commission for Conciliation, Mediation and Arbitration (CCMA'
]



eskom_entities = [
    'Eskom', 'De Ruyter', 'Andrew Etzinger', 'Brian Dames', 'Joffe', 'Hilary Joffe', 'Tshediso Matona', 'Brian Molefe',
    'Koko', 'Matshela Koko'
]

# Topic categories
State_mining  = [
    'State capture & corruption', 'State intervention in mining', 'Daily political business', 'Coal trade relations'
]

Mining_industry = [
    'Mining investments'
]

Mining_communities = [
    'Safety & illegal activities', 'Air pollution', 'Anti-mining activism', 'Coal labor issues'
]

Transition = [
    'Transition politics & climate finance', 'Energy policies & renewables', 'Climate change impact'
]

Energy_crisis = [
    'Eskom crisis', 'Oil & gas alternatives', 'Electricity crisis'
]

# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Determine the topic category
    if topic in State_mining:
        topic_category = 'State role in mining'
    elif topic in Mining_industry:
        topic_category = 'Mining industry'
    elif topic in Mining_communities:
        topic_category = 'Mining communities'
    elif topic in Transition:
        topic_category = 'Transition Politics'
    else topic in Energy_crisis:
        topic_category = 'Energy crisis'
    #else:
    #    topic_category = 'None'

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]

        # Determine the category of the entity
        if entity_name in societal_entities:
            category = 'Societal'
        elif entity_name in unions_entities:
            category = 'Unions'
        elif entity_name in other_business_entities:
            category = 'Other Business'
        elif entity_name in mining_business_entities:
            category = 'Mining Business'
        elif entity_name in international_actors:
            category = 'International'
        elif entity_name in political_entities:
            category = 'Political'
        elif entity_name in eskom_entities:
            category = 'Eskom'
        else:
            category = 'No Entity'

        expanded_data.append([sentence, topic, year, month, entity_name, entity_type, category, topic_category])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entity', 'Type', 'Category', 'Topic Category'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_with_categories.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))

# Summary: How many observations per category
category_counts = df_expanded['Category'].value_counts()
print(category_counts)

# Summary: How many observations per category per topic
category_topic_counts = df_expanded.groupby(['Category', 'Dominant Topic']).size().reset_index(name='Counts')
print(category_topic_counts)

# Summary: How many observations per topic category
topic_category_counts = df_expanded['Topic Category'].value_counts()
print(topic_category_counts)

# Summary: How many observations per category per topic category
category_topic_category_counts = df_expanded.groupby(['Category', 'Topic Category']).size().reset_index(name='Counts')
print(category_topic_category_counts)

# Export the summaries to CSV files
category_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_counts.csv', index=True)
category_topic_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_topic_counts.csv', index=False)
topic_category_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/topic_category_counts.csv', index=True)
category_topic_category_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_topic_category_counts.csv', index=False)
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 3   Many organisations, including the Southern Afr...
# 4   We\re confident this will prove more cost-effe...
# 5   There was widespread support for Britton propo...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual pork-laden legis...
# 8   They contrast the ineffectual pork-laden legis...
# 9   They contrast the ineffectual pork-laden legis...
# 10  In December, the EPA issued an endangerment fi...
# 11  In December, the EPA issued an endangerment fi...
# 12  Hence halting the legislation in the Senate is...
# 13  The major bills are now being pushed by John K...
# 14  The major bills are now being pushed by John K...
# 15  The major bills are now being pushed by John K...
# 16  The problem of relying upon these actors to sa...
# 17  The problem of relying upon these actors to sa...
# 18  The problem of relying upon these actors to sa...
# 19  If Zuma aims, therefore, to persuade the world...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 3                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
#
#                                                Entity    Type   Category  \
# 0                  the Family and Marriage Society SA     ORG  No Entity
# 1                                               Eskom     ORG      Eskom
# 2   the Southern African Faith Communities Environ...     ORG  No Entity
# 3   the Southern African Faith Communities Environ...     ORG  No Entity
# 4                                         Sue Britton  PERSON  No Entity
# 5                                             Britton     ORG  No Entity
# 6                                            Congress     ORG  No Entity
# 7                 the Environmental Protection Agency     ORG  No Entity
# 8                                                 EPA     ORG  No Entity
# 9                               Chevron San Francisco     ORG  No Entity
# 10                                                EPA     ORG  No Entity
# 11                                         GroundWork     ORG  No Entity
# 12                                             Senate     ORG  No Entity
# 13                                         John Kerry  PERSON  No Entity
# 14                                   Joseph Lieberman  PERSON  No Entity
# 15                                     Lindsay Graham  PERSON  No Entity
# 16                                              Eskom     ORG      Eskom
# 17                                                ANC     ORG  Political
# 18                                              House     ORG  No Entity
# 19                                               Zuma  PERSON  Political
#
#          Topic Category
# 0         Energy crisis
# 1         Energy crisis
# 2         Energy crisis
# 3         Energy crisis
# 4         Energy crisis
# 5         Energy crisis
# 6   Transition Politics
# 7   Transition Politics
# 8   Transition Politics
# 9   Transition Politics
# 10  Transition Politics
# 11  Transition Politics
# 12  Transition Politics
# 13  Transition Politics
# 14  Transition Politics
# 15  Transition Politics
# 16  Transition Politics
# 17  Transition Politics
# 18  Transition Politics
# 19  Transition Politics
# Category
# No Entity          40038
# Mining Business     6572
# Eskom               5573
# Political           2464
# Other Business      1580
# Societal             642
# Unions               533
# International        313
# Name: count, dtype: int64
#     Category                         Dominant Topic  Counts
# 0      Eskom                          Air pollution     108
# 1      Eskom                   Anti-mining activism      72
# 2      Eskom                  Climate change impact      58
# 3      Eskom                      Coal labor issues      55
# 4      Eskom                   Coal trade relations     102
# ..       ...                                    ...     ...
# 108   Unions                     Mining investments      10
# 109   Unions            Safety & illegal activities      11
# 110   Unions             State capture & corruption      29
# 111   Unions           State intervention in mining      17
# 112   Unions  Transition politics & climate finance      21
#
# [113 rows x 3 columns]
# Topic Category
# State role in mining    17330
# Mining industry         12769
# Transition Politics     10121
# Mining communities      10111
# Energy crisis            7384
# Name: count, dtype: int64
#            Category        Topic Category  Counts
# 0             Eskom         Energy crisis    1765
# 1             Eskom    Mining communities     345
# 2             Eskom       Mining industry     644
# 3             Eskom  State role in mining    1804
# 4             Eskom   Transition Politics    1015
# 5     International         Energy crisis      22
# 6     International    Mining communities      20
# 7     International       Mining industry       8
# 8     International  State role in mining      67
# 9     International   Transition Politics     196
# 10  Mining Business         Energy crisis     527
# 11  Mining Business    Mining communities    1313
# 12  Mining Business       Mining industry    2552
# 13  Mining Business  State role in mining    1847
# 14  Mining Business   Transition Politics     333
# 15        No Entity         Energy crisis    4449
# 16        No Entity    Mining communities    7595
# 17        No Entity       Mining industry    9119
# 18        No Entity  State role in mining   11130
# 19        No Entity   Transition Politics    7745
# 20   Other Business         Energy crisis     124
# 21   Other Business    Mining communities      89
# 22   Other Business       Mining industry     328
# 23   Other Business  State role in mining     912
# 24   Other Business   Transition Politics     127
# 25        Political         Energy crisis     397
# 26        Political    Mining communities     203
# 27        Political       Mining industry     100
# 28        Political  State role in mining    1356
# 29        Political   Transition Politics     408
# 30         Societal         Energy crisis      64
# 31         Societal    Mining communities     213
# 32         Societal       Mining industry       8
# 33         Societal  State role in mining     102
# 34         Societal   Transition Politics     255
# 35           Unions         Energy crisis      36
# 36           Unions    Mining communities     333
# 37           Unions       Mining industry      10
# 38           Unions  State role in mining     112
# 39           Unions   Transition Politics      42

# %%
import pandas as pd
import ast

# Lists of entities
societal_entities = [
    'Greenpeace', 'Earthlife Africa', 'groundWork', 'Greenpeace Africa', 'CER', 'Save Mapungubwe Coalition',
    'Endangered Wildlife Trust', 'Ezemvelo', 'Ted Blom', 'Chris Yelland', 'Prof Zeelie', 'Engelbrecht',
    'Von Blottnitz', 'Nelson Mandela Metropolitan University', 'CSIR', 'Just Coal', 'Vukani Environmental Justice Movement',
    'Mike Holland', 'Rico Euripidou'
]

unions_entities = [
    'Cosatu', 'NUM', 'National Union of Mineworkers', 'Numsa', 'Amcu', 'Association of Mineworkers and Construction Union',
    'Solidarity', 'Joseph Mathunjwa', 'Jim', 'Lesiba Seshoka', 'Congress of South African Trade Unions',
    'THE National Union of Mineworkers', 'Allied Workers Union'
]

other_business_entities = [
    'SAA', 'Transnet', 'Standard Bank', 'Nedbank', 'Gupta', 'Guptas', 'Brian Molefe', 'Tata', 'IPP', 'Google',
    'Shell', 'Mafutha', 'Royal Dutch Shell', 'Sunbird Energy', 'JSE'
]

mining_business_entities = [
    'Sasol', 'Exxaro', 'Glencore', 'Coal of Africa', 'CoAL', 'Ibutho Coal', 'John Wallington', 'Atha-Africa', 'Optimum',
    'BHP Billiton', 'BEE', 'BHP', 'Tegeta', 'ExxonMobil', 'MMTC', 'Minerals Council SA', 'Umsobomvu Coal',
    'Elitheni', 'AEMFC', 'Teke', 'SAEC', 'Mike Teke', 'Mazizi Msutu', 'Tegeta Exploration and Resources', 'Wescoal',
    'Umthombo Resources', 'ICVL', 'Chamber of Mines', 'Shanduka Coal', 'Delmas Coal', 'Kangra Coal', 'Impala Platinum',
    'AngloGold Ashanti', 'Firestone', 'Xstrata', 'Continental Coal', 'Xstrata Coal'
]

international_actors = [
    'World Bank', 'G20', 'EU', 'UN', 'Intergovernmental Panel on Climate Change (IPCC', 'Xi Jinping',
    'International Energy Agency', 'World Health Organisation'
]

political_entities = [
    'ANC', 'Nersa', 'Treasury', 'Ramaphosa', 'Cyril Ramaphosa', 'Mboweni', 'National Treasury', 'Gwede Mantashe',
    'Gordhan', 'Pravin Gordhan', 'National Energy Regulator of SA', 'Barbara Creecy', 'PCC', 'Presidential Climate Commission',
    'Department of Environmental Affairs', 'Department of Mineral Resources', 'Department of Water Affairs', 'DEA',
    'Edna Molewa', 'Malusi Gigaba', 'Zuma', 'EFF', 'Jacob Zuma', 'Malema', 'Parliament', 'Parks Tau', 'Kelvin',
    'Department of Trade and Industry', 'Department of Energy', 'Fikile Mbalula', 'Department of Mineral Resources and Energy',
    'DMRE', 'Susan Shabangu', 'Ms Shabangu', 'NPA', 'CCMA', 'Commission for Conciliation, Mediation and Arbitration (CCMA'
]

eskom_entities = [
    'Eskom', 'De Ruyter', 'Andrew Etzinger', 'Brian Dames', 'Joffe', 'Hilary Joffe', 'Tshediso Matona', 'Brian Molefe',
    'Koko', 'Matshela Koko'
]

# Topic categories
State_mining  = [
    'State capture & corruption', 'State intervention in mining', 'Daily political business', 'Coal trade relations'
]

Mining_industry = [
    'Mining investments'
]

Mining_communities = [
    'Safety & illegal activities', 'Air pollution', 'Anti-mining activism', 'Coal labor issues'
]

Transition = [
    'Transition politics & climate finance', 'Energy policies & renewables', 'Climate change impact'
]

Energy_crisis = [
    'Eskom crisis', 'Oil & gas alternatives', 'Electricity crisis'
]

# Entity normalization mapping
entity_mapping = {
    'Greenpeace Africa': 'Greenpeace',
    'Zuma': 'Jacob Zuma',
    'BHP': 'BHP Billiton',
    'Ramaphosa': 'Cyril Ramaphosa',
    'Guptas': 'Gupta',
    'National Union of Mineworkers': 'NUM',
    'THE National Union of Mineworkers': 'NUM',
    'Gwede Mantashe': 'Gwede Mantashe',
    'Mantashe': 'Gwede Mantashe'
}

# Load the CSV file with NER predictions
path_to_csv = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv'
df_ner = pd.read_csv(path_to_csv)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize a list to store the expanded rows
expanded_data = []

# Iterate over the DataFrame rows
for index, row in df_ner.iterrows():
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']
    entities = row['Entities']

    # Determine the topic category
    if topic in State_mining:
        topic_category = 'State role in mining'
    elif topic in Mining_industry:
        topic_category = 'Mining industry'
    elif topic in Mining_communities:
        topic_category = 'Mining communities'
    elif topic in Transition:
        topic_category = 'Transition Politics'
    else:
        topic_category = 'Energy crisis'

    # Iterate over the entities to create separate rows for each actor
    for entity in entities:
        entity_name = entity[0]
        entity_type = entity[1]

        # Normalize the entity name
        if entity_name in entity_mapping:
            entity_name = entity_mapping[entity_name]

        # Determine the category and broad category of the entity
        if entity_name in societal_entities:
            category = 'Societal'
            broad_category = 'Societal'
        elif entity_name in unions_entities:
            category = 'Unions'
            broad_category = 'Societal'
        elif entity_name in other_business_entities:
            category = 'Other Business'
            broad_category = 'Business'
        elif entity_name in mining_business_entities:
            category = 'Mining Business'
            broad_category = 'Business'
        elif entity_name in international_actors:
            category = 'International'
            broad_category = 'Political'
        elif entity_name in political_entities:
            category = 'Political'
            broad_category = 'Political'
        elif entity_name in eskom_entities:
            category = 'Eskom'
            broad_category = 'Eskom'
        else:
            category = 'No Entity'
            broad_category = 'No Entity'

        expanded_data.append([sentence, topic, year, month, entity_name, entity_type, category, topic_category, broad_category])

# Create a new DataFrame from the expanded data
df_expanded = pd.DataFrame(expanded_data, columns=['Sentence', 'Dominant Topic', 'Year', 'Month', 'Entity', 'Type', 'Category', 'Topic Category', 'Broad Category'])
df_expanded = df_expanded.drop_duplicates(subset=['Sentence', 'Entity', 'Year', 'Month', 'Dominant Topic'])

# Export the expanded DataFrame as a CSV file
df_expanded.to_csv('/content/drive/MyDrive/Colab Notebooks/ner_predictions_with_categories3.csv', index=False)

# Display the expanded DataFrame
print(df_expanded.head(20))

# Summary: How many observations per category
category_counts = df_expanded['Category'].value_counts()
print(category_counts)

# Summary: How many observations per category per topic
category_topic_counts = df_expanded.groupby(['Category', 'Dominant Topic']).size().reset_index(name='Counts')
print(category_topic_counts)

# Summary: How many observations per topic category
topic_category_counts = df_expanded['Topic Category'].value_counts()
print(topic_category_counts)

# Summary: How many observations per category per topic category
category_topic_category_counts = df_expanded.groupby(['Category', 'Topic Category']).size().reset_index(name='Counts')
print(category_topic_category_counts)

# Summary: How many observations per broad category
broad_category_counts = df_expanded['Broad Category'].value_counts()
print(broad_category_counts)

# Summary: How many observations per broad category per topic category
broad_category_topic_category_counts = df_expanded.groupby(['Broad Category', 'Topic Category']).size().reset_index(name='Counts')
print(broad_category_topic_category_counts)

# Summary: How many observations per broad category per topic category
category_entity_counts = df_expanded.groupby(['Category', 'Entity']).size().reset_index(name='Counts')
print(category_entity_counts)

# Export the summaries to CSV files
#category_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_counts.csv', index=True)
#category_topic_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_topic_counts.csv', index=False)
#topic_category_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/topic_category_counts.csv', index=True)
#category_topic_category_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_topic_category_counts.csv', index=False)
#category_entity_counts.to_csv('/content/drive/MyDrive/Colab Notebooks/category_entity_counts.csv', index=False)
# Out:
#                                              Sentence  \
# 0   Women for Transformation, representing more th...
# 1   Environmental groups rejected the dominance of...
# 2   Many organisations, including the Southern Afr...
# 4   We\re confident this will prove more cost-effe...
# 5   There was widespread support for Britton propo...
# 6   Given the power relations in Congress, this is...
# 7   They contrast the ineffectual pork-laden legis...
# 8   They contrast the ineffectual pork-laden legis...
# 9   They contrast the ineffectual pork-laden legis...
# 10  In December, the EPA issued an endangerment fi...
# 11  In December, the EPA issued an endangerment fi...
# 12  Hence halting the legislation in the Senate is...
# 13  The major bills are now being pushed by John K...
# 14  The major bills are now being pushed by John K...
# 15  The major bills are now being pushed by John K...
# 16  The problem of relying upon these actors to sa...
# 17  The problem of relying upon these actors to sa...
# 18  The problem of relying upon these actors to sa...
# 19  If Zuma aims, therefore, to persuade the world...
# 20  The cuts promised by Sonjica just before Copen...
#
#                            Dominant Topic  Year  Month  \
# 0                            Eskom crisis  2010      1
# 1                            Eskom crisis  2010      1
# 2                            Eskom crisis  2010      1
# 4                            Eskom crisis  2010      1
# 5                            Eskom crisis  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10  Transition politics & climate finance  2010      1
# 11  Transition politics & climate finance  2010      1
# 12  Transition politics & climate finance  2010      1
# 13  Transition politics & climate finance  2010      1
# 14  Transition politics & climate finance  2010      1
# 15  Transition politics & climate finance  2010      1
# 16  Transition politics & climate finance  2010      1
# 17  Transition politics & climate finance  2010      1
# 18  Transition politics & climate finance  2010      1
# 19  Transition politics & climate finance  2010      1
# 20  Transition politics & climate finance  2010      1
#
#                                                Entity    Type   Category  \
# 0                  the Family and Marriage Society SA     ORG  No Entity
# 1                                               Eskom     ORG      Eskom
# 2   the Southern African Faith Communities Environ...     ORG  No Entity
# 4                                         Sue Britton  PERSON  No Entity
# 5                                             Britton     ORG  No Entity
# 6                                            Congress     ORG  No Entity
# 7                 the Environmental Protection Agency     ORG  No Entity
# 8                                                 EPA     ORG  No Entity
# 9                               Chevron San Francisco     ORG  No Entity
# 10                                                EPA     ORG  No Entity
# 11                                         GroundWork     ORG  No Entity
# 12                                             Senate     ORG  No Entity
# 13                                         John Kerry  PERSON  No Entity
# 14                                   Joseph Lieberman  PERSON  No Entity
# 15                                     Lindsay Graham  PERSON  No Entity
# 16                                              Eskom     ORG      Eskom
# 17                                                ANC     ORG  Political
# 18                                              House     ORG  No Entity
# 19                                         Jacob Zuma  PERSON  Political
# 20                                         Copenhagen     ORG  No Entity
#
#          Topic Category Broad Category
# 0         Energy crisis      No Entity
# 1         Energy crisis          Eskom
# 2         Energy crisis      No Entity
# 4         Energy crisis      No Entity
# 5         Energy crisis      No Entity
# 6   Transition Politics      No Entity
# 7   Transition Politics      No Entity
# 8   Transition Politics      No Entity
# 9   Transition Politics      No Entity
# 10  Transition Politics      No Entity
# 11  Transition Politics      No Entity
# 12  Transition Politics      No Entity
# 13  Transition Politics      No Entity
# 14  Transition Politics      No Entity
# 15  Transition Politics      No Entity
# 16  Transition Politics          Eskom
# 17  Transition Politics      Political
# 18  Transition Politics      No Entity
# 19  Transition Politics      Political
# 20  Transition Politics      No Entity
# Category
# No Entity          29383
# Mining Business     4048
# Eskom               3790
# Political           2116
# Other Business      1140
# Societal             448
# Unions               416
# International        231
# Name: count, dtype: int64
#     Category                         Dominant Topic  Counts
# 0      Eskom                          Air pollution      87
# 1      Eskom                   Anti-mining activism      51
# 2      Eskom                  Climate change impact      47
# 3      Eskom                      Coal labor issues      35
# 4      Eskom                   Coal trade relations      76
# ..       ...                                    ...     ...
# 108   Unions                     Mining investments       9
# 109   Unions            Safety & illegal activities      11
# 110   Unions             State capture & corruption      23
# 111   Unions           State intervention in mining      13
# 112   Unions  Transition politics & climate finance      18
#
# [113 rows x 3 columns]
# Topic Category
# State role in mining    12907
# Mining industry          8126
# Transition Politics      7627
# Mining communities       7352
# Energy crisis            5560
# Name: count, dtype: int64
#            Category        Topic Category  Counts
# 0             Eskom         Energy crisis    1251
# 1             Eskom    Mining communities     240
# 2             Eskom       Mining industry     344
# 3             Eskom  State role in mining    1209
# 4             Eskom   Transition Politics     746
# 5     International         Energy crisis      12
# 6     International    Mining communities      13
# 7     International       Mining industry       4
# 8     International  State role in mining      54
# 9     International   Transition Politics     148
# 10  Mining Business         Energy crisis     354
# 11  Mining Business    Mining communities     802
# 12  Mining Business       Mining industry    1455
# 13  Mining Business  State role in mining    1208
# 14  Mining Business   Transition Politics     229
# 15        No Entity         Energy crisis    3419
# 16        No Entity    Mining communities    5664
# 17        No Entity       Mining industry    6046
# 18        No Entity  State role in mining    8465
# 19        No Entity   Transition Politics    5789
# 20   Other Business         Energy crisis      98
# 21   Other Business    Mining communities      69
# 22   Other Business       Mining industry     204
# 23   Other Business  State role in mining     681
# 24   Other Business   Transition Politics      88
# 25        Political         Energy crisis     348
# 26        Political    Mining communities     156
# 27        Political       Mining industry      61
# 28        Political  State role in mining    1138
# 29        Political   Transition Politics     413
# 30         Societal         Energy crisis      46
# 31         Societal    Mining communities     158
# 32         Societal       Mining industry       3
# 33         Societal  State role in mining      60
# 34         Societal   Transition Politics     181
# 35           Unions         Energy crisis      32
# 36           Unions    Mining communities     250
# 37           Unions       Mining industry       9
# 38           Unions  State role in mining      92
# 39           Unions   Transition Politics      33
# Broad Category
# No Entity    29383
# Business      5188
# Eskom         3790
# Political     2347
# Societal       864
# Name: count, dtype: int64
#    Broad Category        Topic Category  Counts
# 0        Business         Energy crisis     452
# 1        Business    Mining communities     871
# 2        Business       Mining industry    1659
# 3        Business  State role in mining    1889
# 4        Business   Transition Politics     317
# 5           Eskom         Energy crisis    1251
# 6           Eskom    Mining communities     240
# 7           Eskom       Mining industry     344
# 8           Eskom  State role in mining    1209
# 9           Eskom   Transition Politics     746
# 10      No Entity         Energy crisis    3419
# 11      No Entity    Mining communities    5664
# 12      No Entity       Mining industry    6046
# 13      No Entity  State role in mining    8465
# 14      No Entity   Transition Politics    5789
# 15      Political         Energy crisis     360
# 16      Political    Mining communities     169
# 17      Political       Mining industry      65
# 18      Political  State role in mining    1192
# 19      Political   Transition Politics     561
# 20       Societal         Energy crisis      78
# 21       Societal    Mining communities     408
# 22       Societal       Mining industry      12
# 23       Societal  State role in mining     152
# 24       Societal   Transition Politics     214
#       Category            Entity  Counts
# 0        Eskom   Andrew Etzinger      19
# 1        Eskom       Brian Dames      32
# 2        Eskom         De Ruyter      71
# 3        Eskom             Eskom    3546
# 4        Eskom      Hilary Joffe      11
# ...        ...               ...     ...
# 11530   Unions  Joseph Mathunjwa      14
# 11531   Unions    Lesiba Seshoka      12
# 11532   Unions               NUM     191
# 11533   Unions             Numsa      43
# 11534   Unions        Solidarity      27
#
# [11535 rows x 3 columns]

# %%
df_subset = df_expanded[df_expanded['Category'] != 'No Entity']

df_subset.to_csv('/content/drive/MyDrive/Colab Notebooks/filtered_ner_predictions_with_categories3.csv', index=False)

# %% [markdown]
# ### Now make Rule looking at the top 40 entries -> Create a dataset containing only sentences connected to one of the top 40 actors (excluding the irrelevant/ false ones, e.g. "coal" or "irp". What about location?
#
# Take out:
# "SAA", "Integrated Resource Plan",
# "Coal", "MW", "Copenhagen", "first onMail & Guardian", "SA", "House", "Mozambique", "LNG",

# %%
# Load the CSV file with top 40 entities
path_to_top_entities = '/content/drive/MyDrive/Colab Notebooks/top_40_entities_summary.csv'
df_top_entities = pd.read_csv(path_to_top_entities)

# Filter out irrelevant terms
irrelevant_terms = ["SAA", "Integrated Resource Plan", "Coal", "MW", "Copenhagen",
                    "first onMail & Guardian", "SA", "House", "Mozambique", "LNG"]
filtered_entities = df_top_entities[~df_top_entities['Entity'].isin(irrelevant_terms)]['Entity'].tolist()

# Load the CSV file with NER predictions
path_to_ner_predictions = '/content/drive/MyDrive/Colab Notebooks/ner_predictions_dtm_spacy5.csv'
df_ner = pd.read_csv(path_to_ner_predictions)

# Convert the string representation of lists in the Entities column back to lists
df_ner['Entities'] = df_ner['Entities'].apply(ast.literal_eval)

# Initialize an empty list to store relevant rows
relevant_rows = []

# Iterate over the DataFrame rows to filter and expand rows
for index, row in df_ner.iterrows():
    entities = row['Entities']
    sentence = row['Sentence']
    topic = row['Dominant Topic']
    year = row['Year']
    month = row['Month']

    # Check if any entity matches the filtered top entities
    for entity, entity_type in entities:
        if entity in filtered_entities and entity_type != 'LOC':  # Exclude locations
            relevant_rows.append([sentence, entity, topic, year, month])

# Create a DataFrame from the relevant rows
df_relevant_sentences = pd.DataFrame(relevant_rows, columns=['Sentence', 'Entity', 'Dominant Topic', 'Year', 'Month'])

# Export the filtered dataset as a CSV file
df_relevant_sentences.to_csv('/content/drive/MyDrive/Colab Notebooks/relevant_sentences_expanded.csv', index=False)

# Display the first few rows of the filtered dataset
print(df_relevant_sentences.head(20))
# Out:
#                                              Sentence Entity  \
# 0   Environmental groups rejected the dominance of...  Eskom
# 1   The problem of relying upon these actors to sa...  Eskom
# 2   The problem of relying upon these actors to sa...    ANC
# 3   In reality, cuts promised in the Long-Term Mit...  Sasol
# 4   As the Eskom tariff hearings organised by the ...  Eskom
# 5   As the Eskom tariff hearings organised by the ...  Eskom
# 6   In reality, cuts promised in the Long-Term Mit...  Sasol
# 7   As the Eskom tariff hearings organised by the ...  Eskom
# 8   As the Eskom tariff hearings organised by the ...  Eskom
# 9   Yet the purpose of the new build programme is ...  Eskom
# 10  The department called this month for public co...  Eskom
# 11  The department called this month for public co...  Eskom
# 12  Several mines are expected to be developed in ...  Eskom
# 13  Several mines are expected to be developed in ...  Eskom
# 14  Several mines are expected to be developed in ...  Eskom
# 15  Committee chairperson Vytjie Mentor, an ANC MP...    ANC
# 16  Committee chairperson Vytjie Mentor, an ANC MP...  Eskom
# 17  Committee chairperson Vytjie Mentor, an ANC MP...    ANC
# 18  Committee chairperson Vytjie Mentor, an ANC MP...  Eskom
# 19  His comments came after Eskom generation head ...  Eskom
#
#                            Dominant Topic  Year  Month
# 0                            Eskom crisis  2010      1
# 1   Transition politics & climate finance  2010      1
# 2   Transition politics & climate finance  2010      1
# 3   Transition politics & climate finance  2010      1
# 4   Transition politics & climate finance  2010      1
# 5   Transition politics & climate finance  2010      1
# 6   Transition politics & climate finance  2010      1
# 7   Transition politics & climate finance  2010      1
# 8   Transition politics & climate finance  2010      1
# 9   Transition politics & climate finance  2010      1
# 10                   Anti-mining activism  2010      1
# 11                   Anti-mining activism  2010      1
# 12                   Anti-mining activism  2010      1
# 13                   Anti-mining activism  2010      1
# 14                   Anti-mining activism  2010      1
# 15                     Electricity crisis  2010      1
# 16                     Electricity crisis  2010      1
# 17                     Electricity crisis  2010      1
# 18                     Electricity crisis  2010      1
# 19                     Electricity crisis  2010      1

# %%
# !pip install matplotlib
# !pip install seaborn
# !pip install scikit-learn
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.13.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.25.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.10/dist-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
